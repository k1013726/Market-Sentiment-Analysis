# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime 

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

#Yahoo!Finance 模組
import yfinance as yf 

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
yf.pdr_override()
symbol = "BTC-USD"
start =datetime.date(2014,9,17)
end = datetime.date.today()

# Read data
df = yf.download(symbol, start, end)
df_Indicators= yf.download(symbol, start, end)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-05-31  27700.529297  27831.677734  26866.453125  27219.658203
# 2023-06-01  27218.412109  27346.105469  26671.720703  26819.972656
# 2023-06-02  26824.556641  27303.861328  26574.644531  27249.589844
# 2023-06-03  27252.324219  27317.052734  26958.003906  27075.128906
# 2023-06-04  27075.123047  27407.019531  26968.224609  27119.066406
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-05-31  27219.658203  15656371534
# 2023-06-01  26819.972656  14678970415
# 2023-06-02  27249.589844  14837415000
# 2023-06-03  27075.128906   8385597470
# 2023-06-04  27119.066406   9360912318
#
# [3183 rows x 6 columns]

# %%
df_Indicators.shape
# Out:
# (3183, 6)

# %%
def SMA(close,n):   
    return close.rolling(window=n).mean()

def WMA(close, n):
    weights = np.array(range(1, n+1))
    sum_weights = np.sum(weights)

    res = close.rolling(window=n).apply(lambda x: np.sum(weights*x) / sum_weights, raw=False)
    return res

def EMA(close, n):    
    res=close.ewm(span=n,min_periods=n).mean()
    return res

def RSI(close, n):
    # RSI
    change = close.diff(1)
    df["Gain"] = change.mask(change < 0, 0)
    df["Loss"] = abs(change.mask(change > 0, 0))
    df["AVG_Gain"] = df.Gain.rolling(n).mean()
    df["AVG_Loss"] = df.Loss.rolling(n).mean()
    df["RS"] = df["AVG_Gain"] / df["AVG_Loss"]
    df["RSI"] = 100 - (100 / (1 + df["RS"]))
    return df["RSI"]


def Stoch_RSI(close, n):
    #Stochastic RSI
    RSI=df["RSI"]
    LL_RSI = RSI.rolling(n).min()
    HH_RSI = RSI.rolling(n).max()         
    return (RSI - LL_RSI) / (HH_RSI - LL_RSI)

def BB(close, n):
    MA = pd.Series(close.rolling(n).mean())
    STD = pd.Series(close.rolling(n).std())
    bb1 = MA + 2 * STD
    df["Upper Bollinger Band"] = pd.Series(bb1)
    bb2 = MA - 2 * STD
    df["Lower Bollinger Band"] = pd.Series(bb2)
    return df["Upper Bollinger Band"],df["Lower Bollinger Band"]

def MACD(close):
    df['EMA12'] = close.ewm(span=12, adjust=False).mean() 
    df['EMA26'] = close.ewm(span=26, adjust= False).mean() 
    return df['EMA12'] - df['EMA26'] 


# 指標副程式(資料,天數)
df_Indicators['SMA_7']=SMA(df['Adj Close'],7)
df_Indicators['SMA_14']=SMA(df['Adj Close'],14)

df_Indicators['EMA_7']=EMA(df['Adj Close'],7)
df_Indicators['EMA_14']=EMA(df['Adj Close'],14)

df_Indicators['RSI']=RSI(df['Adj Close'],14)


df_Indicators['Stoch_RSI']=Stoch_RSI(df['Adj Close'],14)

df_Indicators['Upper_BB']=BB(df['Adj Close'],20)[0]
df_Indicators['Lower_BB']=BB(df['Adj Close'],20)[1]

df_Indicators['MACD']=MACD(df['Adj Close'])
df_Indicators= df_Indicators.dropna()
df_Indicators.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-14  391.691986  411.697998  391.324005  400.869995  400.869995
# 2014-10-15  400.954987  402.226990  388.765991  394.773010  394.773010
# 2014-10-16  394.518005  398.807007  373.070007  382.556000  382.556000
# 2014-10-17  382.756012  385.477997  375.389008  383.757996  383.757996
# 2014-10-18  383.976013  395.157990  378.971008  391.441986  391.441986
#
#               Volume       SMA_7      SMA_14       EMA_7      EMA_14  \
# Date
# 2014-10-14  38491500  373.094291  360.392931  376.986690  371.799589
# 2014-10-15  25267100  379.070435  361.189933  381.434329  374.911777
# 2014-10-16  26990000  381.574720  361.724505  381.714797  375.945126
# 2014-10-17  13600700  384.745575  363.456362  382.225665  376.999326
# 2014-10-18  11416800  388.908857  367.926076  384.529977  378.944982
#
#                   RSI  Stoch_RSI    Upper_BB    Lower_BB       MACD
# Date
# 2014-10-14  54.529605   0.991932  422.829855  317.231348 -10.737706
# 2014-10-15  53.565092   0.965996  419.691379  318.689724  -8.196223
# 2014-10-16  52.336359   0.932954  416.279522  319.914682  -7.086205
# 2014-10-17  58.314477   1.000000  413.813751  320.804254  -6.039892
# 2014-10-18  75.469711   1.000000  415.589314  320.454790  -4.538333

# %%
df_Indicators.shape
# Out:
# (3156, 15)

# %%
#二值化收盤價，昨天比今天高就是跌，就為False
# UpDown=[True]
# for i in range(1,len(df['Close'])):
#     if df['Close'][i]>df['Close'][i-1]:
#         UpDown.append(True)
#     else:
#         UpDown.append(False)
# df['UpDown'] = UpDown

# %%
n = len(df)
train_df = df_Indicators[0:int(n*0.7)]
val_df = df_Indicators[int(n*0.7):int(n*0.9)]
test_df = df_Indicators[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2228, 15), (636, 15), (292, 15))

# %%
# train_df.to_csv('data/train.csv')
# val_df.to_csv('data/val.csv')
# test_df.to_csv('data/test.csv')

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='Close', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %%
multi_window = DataWindow(input_width=7, label_width=7, shift=1, label_columns=['Close'])

# %%
ms_lstm_model = Sequential([
    LSTM(64, return_sequences=True),
    Dense(units=1,kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)

print(f"驗證集的MSE {ms_val_performance['LSTM'][1]}")
print(f"測試集的MSE {ms_performance['LSTM'][1]}")
# Out:
# Epoch 1/50
# 70/70 [==============================] - 4s 16ms/step - loss: 40240012.0000 - mean_absolute_error: 4671.2803 - val_loss: 1831063552.0000 - val_mean_absolute_error: 40998.3828
# Epoch 2/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40230396.0000 - mean_absolute_error: 4670.2476 - val_loss: 1830978304.0000 - val_mean_absolute_error: 40997.3438
# Epoch 3/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40220732.0000 - mean_absolute_error: 4669.2163 - val_loss: 1830893952.0000 - val_mean_absolute_error: 40996.3047
# Epoch 4/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40211080.0000 - mean_absolute_error: 4668.1812 - val_loss: 1830808960.0000 - val_mean_absolute_error: 40995.2734
# Epoch 5/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40201388.0000 - mean_absolute_error: 4667.1455 - val_loss: 1830724352.0000 - val_mean_absolute_error: 40994.2422
# Epoch 6/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40191776.0000 - mean_absolute_error: 4666.1079 - val_loss: 1830639104.0000 - val_mean_absolute_error: 40993.2031
# Epoch 7/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40182164.0000 - mean_absolute_error: 4665.0801 - val_loss: 1830554880.0000 - val_mean_absolute_error: 40992.1680
# Epoch 8/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40172524.0000 - mean_absolute_error: 4664.0464 - val_loss: 1830470016.0000 - val_mean_absolute_error: 40991.1406
# Epoch 9/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40162880.0000 - mean_absolute_error: 4663.0142 - val_loss: 1830385408.0000 - val_mean_absolute_error: 40990.1094
# Epoch 10/50
# 70/70 [==============================] - 1s 13ms/step - loss: 40153276.0000 - mean_absolute_error: 4661.9854 - val_loss: 1830300672.0000 - val_mean_absolute_error: 40989.0781
# Epoch 11/50
# 70/70 [==============================] - 1s 12ms/step - loss: 40143660.0000 - mean_absolute_error: 4660.9536 - val_loss: 1830216064.0000 - val_mean_absolute_error: 40988.0430
# Epoch 12/50
# 70/70 [==============================] - 1s 9ms/step - loss: 40134056.0000 - mean_absolute_error: 4659.9243 - val_loss: 1830132096.0000 - val_mean_absolute_error: 40987.0195
# Epoch 13/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40124476.0000 - mean_absolute_error: 4658.8901 - val_loss: 1830047744.0000 - val_mean_absolute_error: 40985.9844
# Epoch 14/50
# 70/70 [==============================] - 1s 10ms/step - loss: 40114876.0000 - mean_absolute_error: 4657.8623 - val_loss: 1829962880.0000 - val_mean_absolute_error: 40984.9492
# Epoch 15/50
# 70/70 [==============================] - 1s 10ms/step - loss: 40105260.0000 - mean_absolute_error: 4656.8315 - val_loss: 1829878528.0000 - val_mean_absolute_error: 40983.9258
# Epoch 16/50
# 70/70 [==============================] - 1s 9ms/step - loss: 40095616.0000 - mean_absolute_error: 4655.7949 - val_loss: 1829793408.0000 - val_mean_absolute_error: 40982.8906
# Epoch 17/50
# 70/70 [==============================] - 1s 9ms/step - loss: 40086004.0000 - mean_absolute_error: 4654.7651 - val_loss: 1829709056.0000 - val_mean_absolute_error: 40981.8633
# Epoch 18/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40076424.0000 - mean_absolute_error: 4653.7358 - val_loss: 1829624448.0000 - val_mean_absolute_error: 40980.8281
# Epoch 19/50
# 70/70 [==============================] - 1s 9ms/step - loss: 40066776.0000 - mean_absolute_error: 4652.7026 - val_loss: 1829539840.0000 - val_mean_absolute_error: 40979.7930
# Epoch 20/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40057184.0000 - mean_absolute_error: 4651.6689 - val_loss: 1829455104.0000 - val_mean_absolute_error: 40978.7578
# Epoch 21/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40047580.0000 - mean_absolute_error: 4650.6367 - val_loss: 1829370624.0000 - val_mean_absolute_error: 40977.7305
# Epoch 22/50
# 70/70 [==============================] - 1s 9ms/step - loss: 40037984.0000 - mean_absolute_error: 4649.6050 - val_loss: 1829286016.0000 - val_mean_absolute_error: 40976.6992
# Epoch 23/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40028408.0000 - mean_absolute_error: 4648.5801 - val_loss: 1829202048.0000 - val_mean_absolute_error: 40975.6719
# Epoch 24/50
# 70/70 [==============================] - 1s 8ms/step - loss: 40018804.0000 - mean_absolute_error: 4647.5415 - val_loss: 1829117056.0000 - val_mean_absolute_error: 40974.6328
# Epoch 25/50
# 70/70 [==============================] - 1s 7ms/step - loss: 40009188.0000 - mean_absolute_error: 4646.5073 - val_loss: 1829032192.0000 - val_mean_absolute_error: 40973.6055
# Epoch 26/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39999600.0000 - mean_absolute_error: 4645.4761 - val_loss: 1828947840.0000 - val_mean_absolute_error: 40972.5703
# Epoch 27/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39990012.0000 - mean_absolute_error: 4644.4443 - val_loss: 1828863488.0000 - val_mean_absolute_error: 40971.5391
# Epoch 28/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39980428.0000 - mean_absolute_error: 4643.4131 - val_loss: 1828778624.0000 - val_mean_absolute_error: 40970.5039
# Epoch 29/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39970844.0000 - mean_absolute_error: 4642.3833 - val_loss: 1828694016.0000 - val_mean_absolute_error: 40969.4688
# Epoch 30/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39961264.0000 - mean_absolute_error: 4641.3491 - val_loss: 1828609664.0000 - val_mean_absolute_error: 40968.4414
# Epoch 31/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39951664.0000 - mean_absolute_error: 4640.3145 - val_loss: 1828524672.0000 - val_mean_absolute_error: 40967.4062
# Epoch 32/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39942092.0000 - mean_absolute_error: 4639.2817 - val_loss: 1828440448.0000 - val_mean_absolute_error: 40966.3750
# Epoch 33/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39932540.0000 - mean_absolute_error: 4638.2510 - val_loss: 1828355840.0000 - val_mean_absolute_error: 40965.3438
# Epoch 34/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39922968.0000 - mean_absolute_error: 4637.2197 - val_loss: 1828271232.0000 - val_mean_absolute_error: 40964.3047
# Epoch 35/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39913424.0000 - mean_absolute_error: 4636.1899 - val_loss: 1828186624.0000 - val_mean_absolute_error: 40963.2773
# Epoch 36/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39903872.0000 - mean_absolute_error: 4635.1621 - val_loss: 1828102400.0000 - val_mean_absolute_error: 40962.2461
# Epoch 37/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39894324.0000 - mean_absolute_error: 4634.1299 - val_loss: 1828018048.0000 - val_mean_absolute_error: 40961.2266
# Epoch 38/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39884744.0000 - mean_absolute_error: 4633.1006 - val_loss: 1827933824.0000 - val_mean_absolute_error: 40960.1953
# Epoch 39/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39875168.0000 - mean_absolute_error: 4632.0664 - val_loss: 1827848832.0000 - val_mean_absolute_error: 40959.1523
# Epoch 40/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39865640.0000 - mean_absolute_error: 4631.0381 - val_loss: 1827764608.0000 - val_mean_absolute_error: 40958.1289
# Epoch 41/50
# 70/70 [==============================] - 1s 9ms/step - loss: 39856092.0000 - mean_absolute_error: 4630.0059 - val_loss: 1827680512.0000 - val_mean_absolute_error: 40957.1016
# Epoch 42/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39846532.0000 - mean_absolute_error: 4628.9712 - val_loss: 1827595264.0000 - val_mean_absolute_error: 40956.0625
# Epoch 43/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39836988.0000 - mean_absolute_error: 4627.9404 - val_loss: 1827511296.0000 - val_mean_absolute_error: 40955.0312
# Epoch 44/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39827420.0000 - mean_absolute_error: 4626.9082 - val_loss: 1827426688.0000 - val_mean_absolute_error: 40954.0000
# Epoch 45/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39817860.0000 - mean_absolute_error: 4625.8750 - val_loss: 1827341696.0000 - val_mean_absolute_error: 40952.9648
# Epoch 46/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39808356.0000 - mean_absolute_error: 4624.8486 - val_loss: 1827258112.0000 - val_mean_absolute_error: 40951.9414
# Epoch 47/50
# 70/70 [==============================] - 1s 8ms/step - loss: 39798832.0000 - mean_absolute_error: 4623.8154 - val_loss: 1827173504.0000 - val_mean_absolute_error: 40950.9102
# Epoch 48/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39789292.0000 - mean_absolute_error: 4622.7861 - val_loss: 1827088896.0000 - val_mean_absolute_error: 40949.8789
# Epoch 49/50
# 70/70 [==============================] - 0s 7ms/step - loss: 39779724.0000 - mean_absolute_error: 4621.7500 - val_loss: 1827004544.0000 - val_mean_absolute_error: 40948.8477
# Epoch 50/50
# 70/70 [==============================] - 1s 7ms/step - loss: 39770176.0000 - mean_absolute_error: 4620.7192 - val_loss: 1826919680.0000 - val_mean_absolute_error: 40947.8086
# 20/20 [==============================] - 0s 4ms/step - loss: 1826919680.0000 - mean_absolute_error: 40947.8047
# 驗證集的MSE 40947.8046875
# 測試集的MSE 22012.396484375

# %%
ms_mae_test=[ms_val_performance['LSTM'][1],ms_performance['LSTM'][1]]

x = np.arange(len(ms_mae_test))
labels = [ 'Validation','Test']

plt.bar(x,ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')

for i in x:
    plt.text(x=i, y=ms_mae_test[i]+ 0.65, s=str(round(ms_mae_test[i], 3)), ha='center')



plt.xlabel('LSTM Models')
plt.ylabel('Mean absolute error')
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('figure/LSTM MSE.png', dpi=300)
