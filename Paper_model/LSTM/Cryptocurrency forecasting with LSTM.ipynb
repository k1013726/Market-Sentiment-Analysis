# %%
import pandas as pd
from scipy.io import arff
import time
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import math
from keras.layers import Conv1D, LSTM, Lambda, Dropout,Bidirectional
from keras_tuner import RandomSearch
from keras.optimizers import Adam
from sklearn.model_selection import TimeSeriesSplit
from keras.callbacks import EarlyStopping
from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import Callback
import os
import random
import numpy as np
import tensorflow as tf
from pymannkendall import seasonal_test
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import re
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from keras_tuner import HyperParameters

# %%
def build_model(hp,look_back):
    
    model = Sequential()

    # Input layer
    # model.add(LSTM(units=hp.Int('input_units',min_value=100,max_value=256,step=16),
    #               return_sequences=True,input_shape=(look_back, 1)))
    
    # add a  LSTM layer    
    model.add(LSTM(units=hp.Int('input_units',min_value=100,max_value=256,step=16),
                  return_sequences=True,input_shape=(look_back, 1)))
    """    
    model.add(Dropout(rate=hp.Float(
                'dropout',
                min_value=0.0,
                max_value=0.5,
                #default=0.25,
                step=0.05)))

    # Hidden layers
    num_layers = hp.Int('num_layers', 1, 5)

    for i in range(num_layers):
        if i < num_layers - 1:  # Not the last layer
            model.add(LSTM(units=hp.Int(f'lstm_units_{num_layers}{i}', 
                                        min_value=100, max_value=512, step=32), 
                           return_sequences=True))
        else:  # The last layer
            model.add(LSTM(units=hp.Int(f'lstm_units_{num_layers}{i}', 
                                        min_value=100, max_value=512, step=32), 
                           return_sequences=False))
        model.add(Dropout(rate=hp.Float(f'dropout_{num_layers}{i}', 
                                        min_value=0.0, max_value=0.5, 
                                        #default=0.25, 
                                        step=0.05)))
    """
    # Output layer
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(hp.Choice('learning_rate', [1e-1, 1e-2, 1e-3])),
                  loss='mean_absolute_error')
    return model

# %%
def LSTMTrain(data_file,training_ratio,look_back,batch_size):
    start_time = time.time()
    # Load arff file
    data, meta = arff.loadarff((f'../Data/WekaData/{data_file}.arff'))
    data_df = pd.DataFrame(data)
    
    close_index = data_df.columns.get_loc('Close')
    dataset = data_df.iloc[:, close_index:close_index+1].values  # numpy array
    dataset = dataset.astype('float32')


    # define early stopping
    early_stopping5 = EarlyStopping(monitor='val_loss', patience=5, verbose=0)



    class StopAtThreshold(Callback):
        def __init__(self, monitor='loss', threshold=0.01):
            super(StopAtThreshold, self).__init__()
            self.monitor = monitor
            self.threshold = threshold

        def on_epoch_end(self, epoch, logs=None):
            current = logs.get(self.monitor)
            if current is not None and current < self.threshold:
                self.model.stop_training = True

    # create an instance of our custom callback
    stop_at_threshold = StopAtThreshold(monitor='val_loss', threshold=0.015)


    def set_seeds(seed):
        os.environ['PYTHONHASHSEED'] = str(seed)
        random.seed(seed)
        np.random.seed(seed)
        tf.random.set_seed(seed)
        # If you are using CUDA, uncomment the following 2 lines
        # os.environ['TF_DETERMINISTIC_OPS'] = '1'
        # os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

    set_seeds(1234)

    # convert an array of values into a dataset matrix
    def create_dataset(dataset, look_back=1):
        dataX, dataY = [], []
        for i in range(len(dataset)-look_back):
            a = dataset[i:(i+look_back), 0]
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
        return np.array(dataX), np.array(dataY)




    result = seasonal_test(data_df['Close'])
    print(result)
    trend, h, p, z, Tau, s, var_s, slope, intercept = result

    params=re.split(r'\s*,\s', "trend, h, p, z, Tau, s, var_s, slope, intercept")
    for pr in params:
        print(f'{pr}={eval(pr)}')




    # because it's multiplicative, so apply np.log
    dataset = np.log(dataset)

    # Initialize a scaler for the dataset
    #scaler = MinMaxScaler(feature_range=(0, 1))
    # Z-score normalization is useful when the data has outliers or when the distribution of the data is not known. 
    scaler = StandardScaler() 

    # Fit and transform the data to the scaler
    # Split into train and test sets

    training_ratio = training_ratio
    train_data, test_data = train_test_split(dataset, train_size=training_ratio, shuffle=False)

    # Fit the scaler to the training data and transform the training data
    train = scaler.fit_transform(train_data)

    # Use the same scaler to transform the test data
    test = scaler.transform(test_data)
    print(train.shape, test.shape)### Using Multiple Layer Perceptron



    # reshape dataset
    look_back = look_back
    trainX, trainY = create_dataset(train, look_back)
    test_data_with_look_back = np.concatenate((train[-look_back:], test))

    # Create testing data, starting with the end of the training data
    testX, testY = create_dataset(test_data_with_look_back, look_back)

    # create a TimeSeriesSplit object
    tscv = TimeSeriesSplit(n_splits=5)

    tuner = RandomSearch(
        build_model,
        objective='val_loss',
        max_trials=5,
        executions_per_trial=3,
        project_name='bitcoin')

    # define early stopping
    early_stopping15 = EarlyStopping(monitor='val_loss', patience=15, verbose=0)
    # create an instance of our custom callback
    stop_at_threshold = StopAtThreshold(monitor='val_loss', threshold=0.01)
    # perform hyperparameter tuning with time series cross-validation
    for train_index, val_index in tscv.split(trainX):
        X_train, X_val = trainX[train_index], trainX[val_index]
        y_train, y_val = trainY[train_index], trainY[val_index]
        tuner.search(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=10,
            callbacks=[early_stopping15]
            #callbacks=[stop_at_threshold]
        )

    # tuner.search_space_summary()
    # get the best hyperparameters
    best_hp = tuner.get_best_hyperparameters()[0]

    # get the best trial
    best_trial = tuner.oracle.get_best_trials()[0]



    # get the score of the best trial
    best_score = best_trial.score

    # print the score of the best trial
    print(f"Best score: {best_score}")

    # print the values of the best hyperparameters
    for hp in best_hp.values:
        print(f"{hp}: {best_hp.get(hp)}")


    # define early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0)
    # create an instance of our custom callback
    stop_at_threshold = StopAtThreshold(monitor='val_loss', threshold=0.01)



    ntrainX, valX, ntrainY, valY = train_test_split(trainX, trainY, test_size=0.1, shuffle=False)

    #start_time = time.time()

    # create a new HyperParameters object
    new_hp = HyperParameters()

    # set the hyperparameters to the desired values
    # new_hp.Fixed('input_units', 228)
    # new_hp.Fixed('learning_rate', 0.01)
    new_hp.Fixed('input_units', best_hp.values['input_units'])
    new_hp.Fixed('learning_rate', best_hp.values['learning_rate'])

    # build a new model with the specified hyperparameters
    model = build_model(new_hp,look_back)

    # build the best model
    # model = build_model(best_hp)

    # fit the model with early stopping
    history = model.fit(
        ntrainX, ntrainY,
        validation_data=(valX, valY),
        epochs=1000,
        batch_size=batch_size, 
        verbose=0,
        callbacks=[early_stopping15]
        #callbacks=[stop_at_threshold]
    )

    # generate predictions for training
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)





    # Inverse transform the predictions to original scale
    trainPredict_orig = np.exp(scaler.inverse_transform(trainPredict))
    trainY_orig = np.exp(scaler.inverse_transform([trainY]))
    train_mse = mean_squared_error(trainY_orig[0], trainPredict_orig[:,0])
    train_mae = mean_absolute_error(trainY_orig[0], trainPredict_orig[:,0])
    print(f'train MSE: {train_mse:.4f}, RMSE: {math.sqrt(train_mse):.4f}, MAE: {train_mae:.4f}')

    testPredict_orig = np.exp(scaler.inverse_transform(testPredict))
    testY_orig = np.exp(scaler.inverse_transform([testY]))

    # Now you can calculate your evaluation metrics on the original scale
    test_mse = mean_squared_error(testY_orig[0], testPredict_orig[:,0])
    test_mae = mean_absolute_error(testY_orig[0], testPredict_orig[:,0])
    print(f'test MSE: {test_mse:.4f}, RMSE: {math.sqrt(test_mse):.4f}, MAE: {test_mae:.4f}')
    end_time = time.time()
    elapse = end_time-start_time
    print(f'Total time: {elapse//60} minutes, {elapse%60:.4f} seconds.')
    return best_score,best_hp.values['input_units'],best_hp.values['learning_rate'],math.sqrt(train_mse),train_mae,math.sqrt(test_mse),test_mae

# %%
# load a dataset
# data_file = ["BTC-all.arff","BTCUSDT-1h.arff","ETH-all.arff","ETHUSDT-1h.arff"]

data_file=['BTCUSD-1h','BTCUSD-all','BTCUSD-N2Y','BTCUSD-N4Y',
           'ETHUSD-1h','ETHUSD-all','ETHUSD-N2Y','ETHUSD-N4Y',
           'USDCUSD-1h','USDCUSD-all','USDCUSD-N2Y','USDCUSD-N4Y',
           'USDTUSD-1h','USDTUSD-all','USDTUSD-N2Y','USDTUSD-N4Y',  
           'BNBUSD-1h','BNBUSD-all','BNBUSD-N2Y','BNBUSD-N4Y'         
           ]



training_ratio=[0.7,0.8,0.9]
look_back=[1,7,14]
batch_size=[4,8,16,32]

data_file_list= list()
training_ratio_list= list()
look_back_list= list()
batch_size_list= list()

best_score_list= list()
input_units_list= list()
learning_rate_list= list()

train_rmse_list= list()
train_mae_list= list()
test_rmse_list= list()
test_mae_list= list()

for df in data_file:
    for tr in training_ratio:
        for lb in look_back:
            for bs in batch_size:
                data_file_list.append(df)
                training_ratio_list.append(tr)
                look_back_list.append(lb)
                batch_size_list.append(bs)
                resultLSTM=LSTMTrain(df,tr,lb,bs)
                best_score_list.append(resultLSTM[0])
                input_units_list.append(resultLSTM[1])
                learning_rate_list.append(resultLSTM[2])
                train_rmse_list.append(resultLSTM[3])
                train_mae_list.append(resultLSTM[4])
                test_rmse_list.append(resultLSTM[5])
                test_mae_list.append(resultLSTM[6])


Summary={'Data':data_file_list,'training ratio':training_ratio_list,'look back':look_back_list,
         'batch_size_list':batch_size_list,
            'train_mae':train_mae_list,          
            'train_rmse':train_rmse_list,          
            'test_mae':test_mae_list,           
            'test_rmse':test_rmse_list
            
         }

df_Summary = pd.DataFrame(Summary)
df_Summary.to_excel("Summary-LSTM.xlsx",index=False)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 3ms/step
# train MSE: 14330.0941, RMSE: 119.7084, MAE: 78.4636
# test MSE: 4506274.7068, RMSE: 2122.7988, MAE: 2016.2755
# Total time: 0.0 minutes, 9.1812 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 975us/step
# 7/7 [==============================] - 0s 1ms/step
# train MSE: 14983.1919, RMSE: 122.4058, MAE: 84.1929
# test MSE: 4272822.2488, RMSE: 2067.0806, MAE: 1960.2914
# Total time: 0.0 minutes, 5.3539 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 275us/step
# 7/7 [==============================] - 0s 2ms/step
# train MSE: 13342.5409, RMSE: 115.5099, MAE: 75.4336
# test MSE: 4925568.9835, RMSE: 2219.3623, MAE: 2106.3451
# Total time: 0.0 minutes, 4.4878 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# train MSE: 10947.6667, RMSE: 104.6311, MAE: 67.3014
# test MSE: 2955750.4213, RMSE: 1719.2296, MAE: 1617.6375
# Total time: 0.0 minutes, 3.4418 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 5ms/step
# train MSE: 21125.6908, RMSE: 145.3468, MAE: 88.7748
# test MSE: 4383085.9010, RMSE: 2093.5821, MAE: 1768.9019
# Total time: 0.0 minutes, 24.0613 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 6ms/step
# 7/7 [==============================] - 0s 5ms/step
# train MSE: 10948.1820, RMSE: 104.6336, MAE: 68.2270
# test MSE: 5256684.6439, RMSE: 2292.7461, MAE: 2113.1650
# Total time: 0.0 minutes, 11.8681 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 4ms/step
# train MSE: 10383.9626, RMSE: 101.9017, MAE: 63.6554
# test MSE: 13945932.0638, RMSE: 3734.4253, MAE: 3460.3715
# Total time: 0.0 minutes, 8.1313 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 17/17 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 3ms/step
# train MSE: 10443.2972, RMSE: 102.1925, MAE: 65.6208
# test MSE: 3081851.9096, RMSE: 1755.5204, MAE: 1625.8468
# Total time: 0.0 minutes, 7.4328 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 16/16 [==============================] - 0s 7ms/step
# 7/7 [==============================] - 0s 8ms/step
# train MSE: 30172.8707, RMSE: 173.7034, MAE: 114.8026
# test MSE: 224401406.8994, RMSE: 14980.0336, MAE: 14147.8928
# Total time: 0.0 minutes, 26.4317 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 16/16 [==============================] - 0s 9ms/step
# 7/7 [==============================] - 0s 11ms/step
# train MSE: 10764.6852, RMSE: 103.7530, MAE: 65.8291
# test MSE: 81264.4274, RMSE: 285.0692, MAE: 237.5008
# Total time: 0.0 minutes, 11.8678 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 16/16 [==============================] - 0s 8ms/step
# 7/7 [==============================] - 0s 8ms/step
# train MSE: 13224.2016, RMSE: 114.9965, MAE: 80.8115
# test MSE: 1960124.9132, RMSE: 1400.0446, MAE: 1292.0682
# Total time: 0.0 minutes, 9.7481 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (520, 1) (223, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 16/16 [==============================] - 0s 8ms/step
# 7/7 [==============================] - 0s 7ms/step
# train MSE: 30395.5715, RMSE: 174.3433, MAE: 111.7785
# test MSE: 6097773.9477, RMSE: 2469.3671, MAE: 2378.2380
# Total time: 0.0 minutes, 11.8520 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 4ms/step
# train MSE: 201144.0569, RMSE: 448.4909, MAE: 192.7890
# test MSE: 2568611.1881, RMSE: 1602.6887, MAE: 1594.7642
# Total time: 0.0 minutes, 9.1809 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# train MSE: 149613.5943, RMSE: 386.7992, MAE: 168.4791
# test MSE: 1897594.4881, RMSE: 1377.5320, MAE: 1368.1253
# Total time: 0.0 minutes, 4.8496 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# train MSE: 69732.1943, RMSE: 264.0685, MAE: 166.7774
# test MSE: 635048.0044, RMSE: 796.8990, MAE: 784.4939
# Total time: 0.0 minutes, 4.5248 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# train MSE: 97787.4927, RMSE: 312.7099, MAE: 157.1617
# test MSE: 1062619.3331, RMSE: 1030.8343, MAE: 1022.9035
# Total time: 0.0 minutes, 4.4940 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step
# train MSE: 26683.9058, RMSE: 163.3521, MAE: 95.3934
# test MSE: 149139.8579, RMSE: 386.1863, MAE: 370.0018
# Total time: 0.0 minutes, 14.7197 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step
# train MSE: 33487.2166, RMSE: 182.9951, MAE: 113.9735
# test MSE: 115775.7122, RMSE: 340.2583, MAE: 323.7907
# Total time: 0.0 minutes, 15.3147 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 1s 5ms/step
# 5/5 [==============================] - 0s 6ms/step
# train MSE: 20730.8194, RMSE: 143.9820, MAE: 85.6965
# test MSE: 26744.0707, RMSE: 163.5361, MAE: 138.9560
# Total time: 0.0 minutes, 11.5338 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 6ms/step
# train MSE: 46867.0967, RMSE: 216.4881, MAE: 130.2481
# test MSE: 404211.1777, RMSE: 635.7760, MAE: 625.2889
# Total time: 0.0 minutes, 11.7031 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 9ms/step
# 5/5 [==============================] - 0s 12ms/step
# train MSE: 144161.3835, RMSE: 379.6859, MAE: 146.5532
# test MSE: 350842.9349, RMSE: 592.3200, MAE: 465.7820
# Total time: 0.0 minutes, 55.1857 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 8ms/step
# 5/5 [==============================] - 0s 5ms/step
# train MSE: 101952.6218, RMSE: 319.3002, MAE: 186.1936
# test MSE: 1056947.8043, RMSE: 1028.0797, MAE: 1021.5154
# Total time: 0.0 minutes, 12.9477 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 7ms/step
# 5/5 [==============================] - 0s 8ms/step
# train MSE: 60501.5177, RMSE: 245.9706, MAE: 135.1534
# test MSE: 893048.8171, RMSE: 945.0126, MAE: 901.2267
# Total time: 0.0 minutes, 17.3473 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (594, 1) (149, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 19/19 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 6ms/step
# train MSE: 24034.5871, RMSE: 155.0309, MAE: 93.2778
# test MSE: 24102.4906, RMSE: 155.2498, MAE: 130.0486
# Total time: 0.0 minutes, 13.3802 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 8ms/step
# train MSE: 30722.5538, RMSE: 175.2785, MAE: 135.0339
# test MSE: 9858.9235, RMSE: 99.2921, MAE: 83.9061
# Total time: 0.0 minutes, 7.9593 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# train MSE: 49332.6731, RMSE: 222.1096, MAE: 189.0081
# test MSE: 29626.7620, RMSE: 172.1243, MAE: 149.1915
# Total time: 0.0 minutes, 6.0690 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# train MSE: 34173.5146, RMSE: 184.8608, MAE: 123.9142
# test MSE: 118274.5194, RMSE: 343.9106, MAE: 330.9126
# Total time: 0.0 minutes, 8.2712 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# train MSE: 20346.4940, RMSE: 142.6411, MAE: 86.9161
# test MSE: 29250.3315, RMSE: 171.0273, MAE: 145.6061
# Total time: 0.0 minutes, 4.4148 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# train MSE: 26957.2223, RMSE: 164.1865, MAE: 107.1704
# test MSE: 64524.1311, RMSE: 254.0160, MAE: 235.4155
# Total time: 0.0 minutes, 46.1260 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 10ms/step
# train MSE: 36594.8832, RMSE: 191.2979, MAE: 139.3511
# test MSE: 88306.2261, RMSE: 297.1636, MAE: 281.9544
# Total time: 0.0 minutes, 14.9114 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# train MSE: 28255.1687, RMSE: 168.0927, MAE: 104.5945
# test MSE: 71424.8837, RMSE: 267.2543, MAE: 249.2654
# Total time: 0.0 minutes, 9.0206 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# train MSE: 18127.9596, RMSE: 134.6401, MAE: 80.0775
# test MSE: 9242.2977, RMSE: 96.1369, MAE: 78.4996
# Total time: 0.0 minutes, 9.3291 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 9ms/step
# train MSE: 22750.8210, RMSE: 150.8338, MAE: 107.5319
# test MSE: 11955.0268, RMSE: 109.3390, MAE: 86.9818
# Total time: 0.0 minutes, 30.5671 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 9ms/step
# train MSE: 89486.8556, RMSE: 299.1435, MAE: 191.0397
# test MSE: 411982.9208, RMSE: 641.8590, MAE: 634.0825
# Total time: 0.0 minutes, 18.7662 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 8ms/step
# train MSE: 19692.5962, RMSE: 140.3303, MAE: 86.4443
# test MSE: 25955.6968, RMSE: 161.1077, MAE: 136.3943
# Total time: 0.0 minutes, 15.9484 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=24.238186202183755, Tau=0.6096504794308691, s=13797.0, var_s=323971.0, slope=128.40638020000017, intercept=24249.255089483326)
# trend=increasing
# h=True
# p=0.0
# z=24.238186202183755
# Tau=0.6096504794308691
# s=13797.0
# var_s=323971.0
# slope=128.40638020000017
# intercept=24249.255089483326
# (668, 1) (75, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 13ms/step
# train MSE: 20713.8566, RMSE: 143.9231, MAE: 93.6994
# test MSE: 14114.8958, RMSE: 118.8061, MAE: 94.6365
# Total time: 0.0 minutes, 14.6040 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# train MSE: 2828306.4533, RMSE: 1681.7570, MAE: 437.8878
# test MSE: 268110791.9194, RMSE: 16374.0890, MAE: 13104.9269
# Total time: 0.0 minutes, 26.1340 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# train MSE: 1270837.4408, RMSE: 1127.3143, MAE: 303.6391
# test MSE: 131932748.5842, RMSE: 11486.1982, MAE: 8885.9634
# Total time: 0.0 minutes, 19.7634 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# train MSE: 1231283.1549, RMSE: 1109.6320, MAE: 377.8659
# test MSE: 85483553.4116, RMSE: 9245.7316, MAE: 7675.0799
# Total time: 0.0 minutes, 8.5992 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# train MSE: 660700.3662, RMSE: 812.8348, MAE: 262.8160
# test MSE: 48530495.3301, RMSE: 6966.3832, MAE: 5589.0982
# Total time: 0.0 minutes, 7.3042 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 4ms/step
# 32/32 [==============================] - 0s 4ms/step
# train MSE: 308572.0343, RMSE: 555.4926, MAE: 240.2320
# test MSE: 8143799.8909, RMSE: 2853.7344, MAE: 2300.4362
# Total time: 0.0 minutes, 40.3542 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 4ms/step
# 32/32 [==============================] - 0s 4ms/step
# train MSE: 214680.7893, RMSE: 463.3366, MAE: 233.9628
# test MSE: 3316020.0214, RMSE: 1820.9942, MAE: 1410.7410
# Total time: 1.0 minutes, 12.6443 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 5ms/step
# 32/32 [==============================] - 0s 5ms/step
# train MSE: 176087.5777, RMSE: 419.6279, MAE: 171.5455
# test MSE: 3440728.0534, RMSE: 1854.9200, MAE: 1336.2749
# Total time: 0.0 minutes, 46.4644 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 5ms/step
# 32/32 [==============================] - 0s 5ms/step
# train MSE: 221970.4736, RMSE: 471.1374, MAE: 187.8597
# test MSE: 7719510.4117, RMSE: 2778.4007, MAE: 2130.5679
# Total time: 0.0 minutes, 21.6708 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 8ms/step
# 32/32 [==============================] - 0s 8ms/step
# train MSE: 461442.9339, RMSE: 679.2959, MAE: 317.4838
# test MSE: 15963998.4681, RMSE: 3995.4973, MAE: 3389.0607
# Total time: 2.0 minutes, 45.8670 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 9ms/step
# 32/32 [==============================] - 0s 9ms/step
# train MSE: 242568.0411, RMSE: 492.5120, MAE: 245.3183
# test MSE: 5644206.0111, RMSE: 2375.7538, MAE: 1898.2671
# Total time: 2.0 minutes, 1.7981 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 9ms/step
# 32/32 [==============================] - 0s 9ms/step
# train MSE: 158484.9121, RMSE: 398.1016, MAE: 188.0766
# test MSE: 1752048.0828, RMSE: 1323.6495, MAE: 886.9910
# Total time: 1.0 minutes, 7.4346 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2332, 1) (1000, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 73/73 [==============================] - 1s 8ms/step
# 32/32 [==============================] - 0s 9ms/step
# train MSE: 771891.6474, RMSE: 878.5736, MAE: 433.9270
# test MSE: 28258066.1073, RMSE: 5315.8316, MAE: 4590.1153
# Total time: 0.0 minutes, 39.2542 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2665, 1) (667, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 84/84 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# train MSE: 908126.1537, RMSE: 952.9565, MAE: 404.2118
# test MSE: 2286703.1578, RMSE: 1512.1849, MAE: 1201.7212
# Total time: 0.0 minutes, 54.0415 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2665, 1) (667, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 84/84 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# train MSE: 1792922.5927, RMSE: 1339.0006, MAE: 557.8173
# test MSE: 4635667.2605, RMSE: 2153.0600, MAE: 1860.4658
# Total time: 0.0 minutes, 20.3056 seconds.
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=63.63533300873347, Tau=0.73958188697584, s=340894.0, var_s=28697199.999999996, slope=104.69628564902403, intercept=-6431.85650053746)
# trend=increasing
# h=True
# p=0.0
# z=63.63533300873347
# Tau=0.73958188697584
# s=340894.0
# var_s=28697199.999999996
# slope=104.69628564902403
# intercept=-6431.85650053746
# (2665, 1) (667, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 84/84 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# train MSE: 631921.1888, RMSE: 794.9347, MAE: 349.6492
# test MSE: 721957.8290, RMSE: 849.6810, MAE: 540.5866
# Total time: 0.0 minutes, 10.2616 seconds.
# ...
# learning_rate: 0.01
# 18/18 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 4ms/step
# train MSE: 164.5227, RMSE: 12.8266, MAE: 9.2195
# test MSE: 21.0009, RMSE: 4.5827, MAE: 3.4081
# Total time: 0.0 minutes, 6.8674 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (577, 1) (145, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 18/18 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step
# train MSE: 202.4244, RMSE: 14.2276, MAE: 9.2831
# test MSE: 18.7804, RMSE: 4.3336, MAE: 3.0225
# Total time: 0.0 minutes, 9.8964 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (577, 1) (145, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 18/18 [==============================] - 0s 8ms/step
# 5/5 [==============================] - 0s 7ms/step
# train MSE: 223.9199, RMSE: 14.9640, MAE: 11.5986
# test MSE: 242.0086, RMSE: 15.5566, MAE: 14.9551
# Total time: 0.0 minutes, 29.8928 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (577, 1) (145, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 18/18 [==============================] - 0s 8ms/step
# 5/5 [==============================] - 0s 4ms/step
# train MSE: 224.2896, RMSE: 14.9763, MAE: 10.6828
# test MSE: 205.0521, RMSE: 14.3196, MAE: 13.6260
# Total time: 0.0 minutes, 27.0396 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (577, 1) (145, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 18/18 [==============================] - 0s 8ms/step
# 5/5 [==============================] - 0s 10ms/step
# train MSE: 162.2904, RMSE: 12.7393, MAE: 8.5891
# test MSE: 20.3993, RMSE: 4.5166, MAE: 3.3094
# Total time: 0.0 minutes, 18.6400 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (577, 1) (145, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 18/18 [==============================] - 0s 9ms/step
# 5/5 [==============================] - 0s 8ms/step
# train MSE: 137.0517, RMSE: 11.7069, MAE: 8.0188
# test MSE: 37.5494, RMSE: 6.1278, MAE: 5.1493
# Total time: 0.0 minutes, 14.0833 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 780us/step
# 3/3 [==============================] - 0s 0s/step
# train MSE: 140.3701, RMSE: 11.8478, MAE: 8.0187
# test MSE: 15.6745, RMSE: 3.9591, MAE: 3.2418
# Total time: 0.0 minutes, 12.7386 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 782us/step
# 3/3 [==============================] - 0s 3ms/step
# train MSE: 149.0020, RMSE: 12.2066, MAE: 8.5340
# test MSE: 33.3403, RMSE: 5.7741, MAE: 5.2539
# Total time: 0.0 minutes, 5.3588 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 0s/step
# train MSE: 181.3166, RMSE: 13.4654, MAE: 9.4198
# test MSE: 104.3813, RMSE: 10.2167, MAE: 9.8263
# Total time: 0.0 minutes, 6.6525 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train MSE: 163.8389, RMSE: 12.8000, MAE: 8.6610
# test MSE: 8.5324, RMSE: 2.9210, MAE: 2.1188
# Total time: 0.0 minutes, 4.3355 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 0s/step
# train MSE: 138.1017, RMSE: 11.7517, MAE: 7.8718
# test MSE: 9.1666, RMSE: 3.0276, MAE: 2.2263
# Total time: 0.0 minutes, 14.3742 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 3ms/step
# train MSE: 386.9898, RMSE: 19.6721, MAE: 12.3877
# test MSE: 73.7282, RMSE: 8.5865, MAE: 8.1162
# Total time: 0.0 minutes, 10.8971 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 9ms/step
# train MSE: 140.4569, RMSE: 11.8515, MAE: 7.8673
# test MSE: 10.0464, RMSE: 3.1696, MAE: 2.3553
# Total time: 0.0 minutes, 11.5904 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 21/21 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# train MSE: 159.8843, RMSE: 12.6445, MAE: 9.1226
# test MSE: 79.6611, RMSE: 8.9253, MAE: 8.4804
# Total time: 0.0 minutes, 6.9988 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 20/20 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 8ms/step
# train MSE: 137.9798, RMSE: 11.7465, MAE: 8.0275
# test MSE: 32.4098, RMSE: 5.6930, MAE: 5.1009
# Total time: 0.0 minutes, 45.3449 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 20/20 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 9ms/step
# train MSE: 444.8532, RMSE: 21.0915, MAE: 13.3387
# test MSE: 97.7769, RMSE: 9.8882, MAE: 9.4148
# Total time: 0.0 minutes, 15.2949 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 20/20 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 14ms/step
# train MSE: 134.2672, RMSE: 11.5874, MAE: 8.0832
# test MSE: 18.1312, RMSE: 4.2581, MAE: 3.4761
# Total time: 0.0 minutes, 13.0435 seconds.
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-21.020603123627403, Tau=-0.5367977528089888, s=-11466.0, var_s=297480.0, slope=-3.5306490844155842, intercept=405.3716364109848)
# trend=decreasing
# h=True
# p=0.0
# z=-21.020603123627403
# Tau=-0.5367977528089888
# s=-11466.0
# var_s=297480.0
# slope=-3.5306490844155842
# intercept=405.3716364109848
# (649, 1) (73, 1)
# INFO:tensorflow:Reloading Tuner from .\bitcoin\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Best score: 0.037774731094638504
# input_units: 228
# learning_rate: 0.01
# 20/20 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 16ms/step
# train MSE: 250.5279, RMSE: 15.8281, MAE: 10.4162
# test MSE: 62.5933, RMSE: 7.9116, MAE: 7.2886
# Total time: 0.0 minutes, 7.9579 seconds.
