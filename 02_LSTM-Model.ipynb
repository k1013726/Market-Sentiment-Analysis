# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell,ConvLSTM2D

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
df = pd.read_csv('FinBERT/Data_final/BTC_final.csv').drop(['CionScore'],axis=1)
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#      CoinDate        Open        High         Low       Close      Volume
# 0  2014-10-01  387.427002  391.378998  380.779999  383.614990  26229400.0
# 1  2014-10-02  383.988007  385.497009  372.946014  375.071991  21777700.0
# 2  2014-10-03  375.181000  377.695007  357.859009  359.511993  30901200.0
# 3  2014-10-04  359.891998  364.487000  325.885986  328.865997  47236500.0
# 4  2014-10-05  328.915985  341.800995  289.295990  320.510010  83308096.0

# %%
#將時間轉換為數值，以方便後續可以運算
timestamp_s = pd.to_datetime(df['CoinDate']).map(datetime.datetime.timestamp)
df['Coin_timestamp'] = timestamp_s
df = df.drop(['CoinDate'], axis=1)
df.head()
# Out:
#          Open        High         Low       Close      Volume  Coin_timestamp
# 0  387.427002  391.378998  380.779999  383.614990  26229400.0    1.412093e+09
# 1  383.988007  385.497009  372.946014  375.071991  21777700.0    1.412179e+09
# 2  375.181000  377.695007  357.859009  359.511993  30901200.0    1.412266e+09
# 3  359.891998  364.487000  325.885986  328.865997  47236500.0    1.412352e+09
# 4  328.915985  341.800995  289.295990  320.510010  83308096.0    1.412438e+09

# %%
df.shape
# Out:
# (3073, 6)

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# Open            3073.0  1.308273e+04  1.609732e+04  1.768970e+02
# High            3073.0  1.340983e+04  1.650774e+04  2.117310e+02
# Low             3073.0  1.272014e+04  1.562394e+04  1.715100e+02
# Close           3073.0  1.308870e+04  1.609327e+04  1.781030e+02
# Volume          3073.0  1.656535e+10  1.985180e+10  5.914570e+06
# Coin_timestamp  3073.0  1.544803e+09  7.665780e+07  1.412093e+09
#
#                          25%           50%           75%           max
# Open            7.155550e+02  7.296165e+03  1.781364e+04  6.754973e+04
# High            7.364520e+02  7.447272e+03  1.839395e+04  6.878962e+04
# Low             7.052600e+02  7.153306e+03  1.738255e+04  6.638206e+04
# Close           7.164110e+02  7.302089e+03  1.789970e+04  6.756683e+04
# Volume          1.123540e+08  8.660880e+09  2.806636e+10  3.509680e+11
# Coin_timestamp  1.478448e+09  1.544803e+09  1.611158e+09  1.677514e+09

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2151, 6), (614, 6), (308, 6))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %%
train_df.describe().transpose()
# Out:
#                  count      mean       std  min       25%       50%       75%  \
# Open            2151.0  0.215505  0.212028  0.0  0.013279  0.177392  0.395715
# High            2151.0  0.213083  0.211984  0.0  0.011472  0.173223  0.394385
# Low             2151.0  0.215220  0.210212  0.0  0.013610  0.179136  0.394656
# Close           2151.0  0.215487  0.211927  0.0  0.013218  0.177176  0.395720
# Volume          2151.0  0.104343  0.155503  0.0  0.000735  0.025612  0.165412
# Coin_timestamp  2151.0  0.500000  0.288877  0.0  0.250000  0.500000  0.750000
#
#                 max
# Open            1.0
# High            1.0
# Low             1.0
# Close           1.0
# Volume          1.0
# Coin_timestamp  1.0

# %%
# train_df.to_csv('data/train.csv')
# val_df.to_csv('data/val.csv')
# test_df.to_csv('data/test.csv')

# %%
# train_df = pd.read_csv('../data/train.csv', index_col=0)
# val_df = pd.read_csv('../data/val.csv', index_col=0)
# test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (2151, 6) (614, 6) (308, 6)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='Close', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Multi-step model

# %%
multi_window = DataWindow(input_width=7, label_width=7, shift=1, label_columns=['Close'])

# %%
ms_mae_val = []
ms_mae_test = []

# %%
for i in range(10):
    ms_lstm_model = Sequential([
        LSTM(64, return_sequences=True),
        Dense(units=1,kernel_initializer=tf.initializers.zeros),
    ])

    history = compile_and_fit(ms_lstm_model, multi_window)

    ms_val_performance = {}
    ms_performance = {}

    ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
    ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)

    print(f"驗證集的MSE {ms_val_performance['LSTM'][1]}")
    print(f"測試集的MSE {ms_performance['LSTM'][1]}")
# Out:
# Epoch 1/50
# 67/67 [==============================] - 2s 10ms/step - loss: 0.0332 - mean_absolute_error: 0.1245 - val_loss: 1.7079 - val_mean_absolute_error: 1.1477
# Epoch 2/50
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0519 - val_loss: 0.4566 - val_mean_absolute_error: 0.5141
# Epoch 3/50
# 67/67 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0300 - val_loss: 0.3142 - val_mean_absolute_error: 0.4393
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0215 - val_loss: 0.2280 - val_mean_absolute_error: 0.3793
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 6.6999e-04 - mean_absolute_error: 0.0169 - val_loss: 0.1754 - val_mean_absolute_error: 0.3339
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.9620e-04 - mean_absolute_error: 0.0142 - val_loss: 0.1363 - val_mean_absolute_error: 0.2890
# Epoch 7/50
# 67/67 [==============================] - 0s 4ms/step - loss: 4.1862e-04 - mean_absolute_error: 0.0126 - val_loss: 0.1210 - val_mean_absolute_error: 0.2725
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.7988e-04 - mean_absolute_error: 0.0115 - val_loss: 0.1125 - val_mean_absolute_error: 0.2615
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.4846e-04 - mean_absolute_error: 0.0107 - val_loss: 0.1068 - val_mean_absolute_error: 0.2548
# Epoch 10/50
# 67/67 [==============================] - 0s 4ms/step - loss: 3.3025e-04 - mean_absolute_error: 0.0100 - val_loss: 0.1111 - val_mean_absolute_error: 0.2632
# Epoch 11/50
# 67/67 [==============================] - 0s 4ms/step - loss: 3.1773e-04 - mean_absolute_error: 0.0096 - val_loss: 0.1042 - val_mean_absolute_error: 0.2524
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1060e-04 - mean_absolute_error: 0.0094 - val_loss: 0.1143 - val_mean_absolute_error: 0.2686
# Epoch 13/50
# 67/67 [==============================] - 0s 6ms/step - loss: 2.9777e-04 - mean_absolute_error: 0.0091 - val_loss: 0.1067 - val_mean_absolute_error: 0.2573
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9321e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0998 - val_mean_absolute_error: 0.2464
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8792e-04 - mean_absolute_error: 0.0088 - val_loss: 0.1104 - val_mean_absolute_error: 0.2634
# Epoch 16/50
# 67/67 [==============================] - 0s 6ms/step - loss: 2.8830e-04 - mean_absolute_error: 0.0088 - val_loss: 0.1088 - val_mean_absolute_error: 0.2616
# Epoch 17/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8509e-04 - mean_absolute_error: 0.0086 - val_loss: 0.1081 - val_mean_absolute_error: 0.2604
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1081 - mean_absolute_error: 0.2604
# 驗證集的MSE 0.2604219317436218
# 測試集的MSE 0.055513009428977966
# Epoch 1/50
# 67/67 [==============================] - 4s 15ms/step - loss: 0.0329 - mean_absolute_error: 0.1243 - val_loss: 1.6183 - val_mean_absolute_error: 1.1116
# Epoch 2/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0514 - val_loss: 0.4965 - val_mean_absolute_error: 0.5471
# Epoch 3/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0316 - val_loss: 0.3292 - val_mean_absolute_error: 0.4495
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0228 - val_loss: 0.2401 - val_mean_absolute_error: 0.3924
# Epoch 5/50
# 67/67 [==============================] - 0s 6ms/step - loss: 7.1292e-04 - mean_absolute_error: 0.0176 - val_loss: 0.1843 - val_mean_absolute_error: 0.3446
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 5.0932e-04 - mean_absolute_error: 0.0145 - val_loss: 0.1528 - val_mean_absolute_error: 0.3121
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.1809e-04 - mean_absolute_error: 0.0125 - val_loss: 0.1375 - val_mean_absolute_error: 0.2953
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.7865e-04 - mean_absolute_error: 0.0116 - val_loss: 0.1283 - val_mean_absolute_error: 0.2845
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.5303e-04 - mean_absolute_error: 0.0108 - val_loss: 0.1192 - val_mean_absolute_error: 0.2728
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2870e-04 - mean_absolute_error: 0.0100 - val_loss: 0.1132 - val_mean_absolute_error: 0.2643
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1791e-04 - mean_absolute_error: 0.0097 - val_loss: 0.1195 - val_mean_absolute_error: 0.2748
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1126e-04 - mean_absolute_error: 0.0094 - val_loss: 0.1043 - val_mean_absolute_error: 0.2516
# Epoch 13/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.0362e-04 - mean_absolute_error: 0.0092 - val_loss: 0.1172 - val_mean_absolute_error: 0.2726
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9729e-04 - mean_absolute_error: 0.0090 - val_loss: 0.1114 - val_mean_absolute_error: 0.2630
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9246e-04 - mean_absolute_error: 0.0089 - val_loss: 0.1111 - val_mean_absolute_error: 0.2629
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1111 - mean_absolute_error: 0.2629
# 驗證集的MSE 0.2629072368144989
# 測試集的MSE 0.052390649914741516
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0332 - mean_absolute_error: 0.1242 - val_loss: 1.6674 - val_mean_absolute_error: 1.1342
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0509 - val_loss: 0.4612 - val_mean_absolute_error: 0.5204
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0292 - val_loss: 0.3138 - val_mean_absolute_error: 0.4372
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 0.2313 - val_mean_absolute_error: 0.3803
# Epoch 5/50
# 67/67 [==============================] - 0s 6ms/step - loss: 6.4902e-04 - mean_absolute_error: 0.0164 - val_loss: 0.1771 - val_mean_absolute_error: 0.3305
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.7484e-04 - mean_absolute_error: 0.0137 - val_loss: 0.1515 - val_mean_absolute_error: 0.3049
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.9887e-04 - mean_absolute_error: 0.0121 - val_loss: 0.1353 - val_mean_absolute_error: 0.2884
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.6355e-04 - mean_absolute_error: 0.0111 - val_loss: 0.1222 - val_mean_absolute_error: 0.2726
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.3947e-04 - mean_absolute_error: 0.0104 - val_loss: 0.1165 - val_mean_absolute_error: 0.2672
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2154e-04 - mean_absolute_error: 0.0099 - val_loss: 0.1123 - val_mean_absolute_error: 0.2624
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1074e-04 - mean_absolute_error: 0.0095 - val_loss: 0.1148 - val_mean_absolute_error: 0.2688
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0463e-04 - mean_absolute_error: 0.0094 - val_loss: 0.1056 - val_mean_absolute_error: 0.2547
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9772e-04 - mean_absolute_error: 0.0091 - val_loss: 0.1172 - val_mean_absolute_error: 0.2740
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9059e-04 - mean_absolute_error: 0.0090 - val_loss: 0.1066 - val_mean_absolute_error: 0.2569
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8720e-04 - mean_absolute_error: 0.0088 - val_loss: 0.1127 - val_mean_absolute_error: 0.2655
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1127 - mean_absolute_error: 0.2655
# 驗證集的MSE 0.2655491232872009
# 測試集的MSE 0.05317193269729614
# Epoch 1/50
# 67/67 [==============================] - 2s 11ms/step - loss: 0.0317 - mean_absolute_error: 0.1222 - val_loss: 1.4797 - val_mean_absolute_error: 1.0615
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0488 - val_loss: 0.5261 - val_mean_absolute_error: 0.5851
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0299 - val_loss: 0.3680 - val_mean_absolute_error: 0.4923
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0220 - val_loss: 0.2518 - val_mean_absolute_error: 0.4066
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 7.1398e-04 - mean_absolute_error: 0.0176 - val_loss: 0.1990 - val_mean_absolute_error: 0.3620
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 5.0342e-04 - mean_absolute_error: 0.0142 - val_loss: 0.1733 - val_mean_absolute_error: 0.3362
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.2912e-04 - mean_absolute_error: 0.0128 - val_loss: 0.1521 - val_mean_absolute_error: 0.3103
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.7924e-04 - mean_absolute_error: 0.0115 - val_loss: 0.1476 - val_mean_absolute_error: 0.3050
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.5615e-04 - mean_absolute_error: 0.0108 - val_loss: 0.1354 - val_mean_absolute_error: 0.2880
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.4506e-04 - mean_absolute_error: 0.0104 - val_loss: 0.1349 - val_mean_absolute_error: 0.2870
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2781e-04 - mean_absolute_error: 0.0100 - val_loss: 0.1374 - val_mean_absolute_error: 0.2908
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1876e-04 - mean_absolute_error: 0.0097 - val_loss: 0.1342 - val_mean_absolute_error: 0.2871
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1907e-04 - mean_absolute_error: 0.0097 - val_loss: 0.1270 - val_mean_absolute_error: 0.2767
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0256e-04 - mean_absolute_error: 0.0092 - val_loss: 0.1282 - val_mean_absolute_error: 0.2786
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0001e-04 - mean_absolute_error: 0.0092 - val_loss: 0.1294 - val_mean_absolute_error: 0.2812
# Epoch 16/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0324e-04 - mean_absolute_error: 0.0093 - val_loss: 0.1227 - val_mean_absolute_error: 0.2715
# Epoch 17/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9245e-04 - mean_absolute_error: 0.0089 - val_loss: 0.1276 - val_mean_absolute_error: 0.2800
# Epoch 18/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8866e-04 - mean_absolute_error: 0.0088 - val_loss: 0.1264 - val_mean_absolute_error: 0.2779
# Epoch 19/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9034e-04 - mean_absolute_error: 0.0089 - val_loss: 0.1315 - val_mean_absolute_error: 0.2858
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1315 - mean_absolute_error: 0.2858
# 驗證集的MSE 0.2858068346977234
# 測試集的MSE 0.05314365401864052
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0304 - mean_absolute_error: 0.1192 - val_loss: 1.5773 - val_mean_absolute_error: 1.0946
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0483 - val_loss: 0.5467 - val_mean_absolute_error: 0.5795
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0301 - val_loss: 0.3721 - val_mean_absolute_error: 0.4858
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 0.2600 - val_mean_absolute_error: 0.4079
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 7.0119e-04 - mean_absolute_error: 0.0172 - val_loss: 0.2043 - val_mean_absolute_error: 0.3616
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 5.0339e-04 - mean_absolute_error: 0.0142 - val_loss: 0.1670 - val_mean_absolute_error: 0.3236
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.1476e-04 - mean_absolute_error: 0.0124 - val_loss: 0.1416 - val_mean_absolute_error: 0.2938
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.6673e-04 - mean_absolute_error: 0.0111 - val_loss: 0.1319 - val_mean_absolute_error: 0.2847
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.4257e-04 - mean_absolute_error: 0.0103 - val_loss: 0.1263 - val_mean_absolute_error: 0.2785
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.3231e-04 - mean_absolute_error: 0.0101 - val_loss: 0.1147 - val_mean_absolute_error: 0.2617
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2076e-04 - mean_absolute_error: 0.0098 - val_loss: 0.1192 - val_mean_absolute_error: 0.2699
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0565e-04 - mean_absolute_error: 0.0093 - val_loss: 0.1206 - val_mean_absolute_error: 0.2732
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0041e-04 - mean_absolute_error: 0.0092 - val_loss: 0.1208 - val_mean_absolute_error: 0.2735
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1208 - mean_absolute_error: 0.2735
# 驗證集的MSE 0.2734604775905609
# 測試集的MSE 0.048920199275016785
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0306 - mean_absolute_error: 0.1181 - val_loss: 1.5133 - val_mean_absolute_error: 1.0716
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0468 - val_loss: 0.4170 - val_mean_absolute_error: 0.4841
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0279 - val_loss: 0.2780 - val_mean_absolute_error: 0.4101
# Epoch 4/50
# 67/67 [==============================] - 0s 6ms/step - loss: 9.6081e-04 - mean_absolute_error: 0.0197 - val_loss: 0.1782 - val_mean_absolute_error: 0.3255
# Epoch 5/50
# 67/67 [==============================] - 0s 6ms/step - loss: 5.7472e-04 - mean_absolute_error: 0.0155 - val_loss: 0.1466 - val_mean_absolute_error: 0.3006
# Epoch 6/50
# 67/67 [==============================] - 0s 6ms/step - loss: 4.3299e-04 - mean_absolute_error: 0.0130 - val_loss: 0.1161 - val_mean_absolute_error: 0.2616
# Epoch 7/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.7907e-04 - mean_absolute_error: 0.0117 - val_loss: 0.1060 - val_mean_absolute_error: 0.2517
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.4363e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0922 - val_mean_absolute_error: 0.2317
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2768e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0841 - val_mean_absolute_error: 0.2194
# Epoch 10/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.1054e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0850 - val_mean_absolute_error: 0.2232
# Epoch 11/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.0477e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0816 - val_mean_absolute_error: 0.2180
# Epoch 12/50
# 67/67 [==============================] - 0s 6ms/step - loss: 2.9615e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0829 - val_mean_absolute_error: 0.2215
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9467e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0835 - val_mean_absolute_error: 0.2230
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8887e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0857 - val_mean_absolute_error: 0.2268
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0857 - mean_absolute_error: 0.2268
# 驗證集的MSE 0.22684812545776367
# 測試集的MSE 0.048126161098480225
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0320 - mean_absolute_error: 0.1209 - val_loss: 1.5433 - val_mean_absolute_error: 1.0856
# Epoch 2/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0055 - mean_absolute_error: 0.0466 - val_loss: 0.5128 - val_mean_absolute_error: 0.5723
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0288 - val_loss: 0.3428 - val_mean_absolute_error: 0.4814
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0206 - val_loss: 0.2301 - val_mean_absolute_error: 0.3924
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 6.2316e-04 - mean_absolute_error: 0.0163 - val_loss: 0.1782 - val_mean_absolute_error: 0.3454
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.6996e-04 - mean_absolute_error: 0.0136 - val_loss: 0.1410 - val_mean_absolute_error: 0.3004
# Epoch 7/50
# 67/67 [==============================] - 0s 6ms/step - loss: 4.0810e-04 - mean_absolute_error: 0.0121 - val_loss: 0.1266 - val_mean_absolute_error: 0.2837
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.6623e-04 - mean_absolute_error: 0.0109 - val_loss: 0.1299 - val_mean_absolute_error: 0.2892
# Epoch 9/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.4718e-04 - mean_absolute_error: 0.0103 - val_loss: 0.1244 - val_mean_absolute_error: 0.2823
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2953e-04 - mean_absolute_error: 0.0099 - val_loss: 0.1216 - val_mean_absolute_error: 0.2778
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.3050e-04 - mean_absolute_error: 0.0099 - val_loss: 0.1297 - val_mean_absolute_error: 0.2899
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1114e-04 - mean_absolute_error: 0.0093 - val_loss: 0.1204 - val_mean_absolute_error: 0.2756
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0665e-04 - mean_absolute_error: 0.0093 - val_loss: 0.1139 - val_mean_absolute_error: 0.2658
# Epoch 14/50
# 67/67 [==============================] - 0s 6ms/step - loss: 2.9689e-04 - mean_absolute_error: 0.0090 - val_loss: 0.1249 - val_mean_absolute_error: 0.2824
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9807e-04 - mean_absolute_error: 0.0089 - val_loss: 0.1207 - val_mean_absolute_error: 0.2760
# Epoch 16/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8779e-04 - mean_absolute_error: 0.0087 - val_loss: 0.1146 - val_mean_absolute_error: 0.2674
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1146 - mean_absolute_error: 0.2674
# 驗證集的MSE 0.2673511803150177
# 測試集的MSE 0.054198894649744034
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0326 - mean_absolute_error: 0.1229 - val_loss: 1.4396 - val_mean_absolute_error: 1.0386
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_absolute_error: 0.0487 - val_loss: 0.4327 - val_mean_absolute_error: 0.4995
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0289 - val_loss: 0.2930 - val_mean_absolute_error: 0.4274
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0205 - val_loss: 0.2202 - val_mean_absolute_error: 0.3777
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 6.0478e-04 - mean_absolute_error: 0.0161 - val_loss: 0.1679 - val_mean_absolute_error: 0.3272
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.5245e-04 - mean_absolute_error: 0.0135 - val_loss: 0.1381 - val_mean_absolute_error: 0.2942
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.8516e-04 - mean_absolute_error: 0.0119 - val_loss: 0.1224 - val_mean_absolute_error: 0.2764
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.5107e-04 - mean_absolute_error: 0.0109 - val_loss: 0.1095 - val_mean_absolute_error: 0.2600
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.3495e-04 - mean_absolute_error: 0.0103 - val_loss: 0.1061 - val_mean_absolute_error: 0.2575
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1593e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0967 - val_mean_absolute_error: 0.2430
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0826e-04 - mean_absolute_error: 0.0094 - val_loss: 0.1017 - val_mean_absolute_error: 0.2530
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9941e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0932 - val_mean_absolute_error: 0.2385
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9781e-04 - mean_absolute_error: 0.0090 - val_loss: 0.1022 - val_mean_absolute_error: 0.2539
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9458e-04 - mean_absolute_error: 0.0090 - val_loss: 0.1043 - val_mean_absolute_error: 0.2577
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8742e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0972 - val_mean_absolute_error: 0.2450
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0972 - mean_absolute_error: 0.2450
# 驗證集的MSE 0.24499747157096863
# 測試集的MSE 0.05461902171373367
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0325 - mean_absolute_error: 0.1238 - val_loss: 1.6329 - val_mean_absolute_error: 1.1194
# Epoch 2/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0522 - val_loss: 0.4404 - val_mean_absolute_error: 0.4992
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0300 - val_loss: 0.3089 - val_mean_absolute_error: 0.4364
# Epoch 4/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0214 - val_loss: 0.2212 - val_mean_absolute_error: 0.3741
# Epoch 5/50
# 67/67 [==============================] - 0s 5ms/step - loss: 6.5106e-04 - mean_absolute_error: 0.0166 - val_loss: 0.1681 - val_mean_absolute_error: 0.3258
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.7528e-04 - mean_absolute_error: 0.0139 - val_loss: 0.1389 - val_mean_absolute_error: 0.2962
# Epoch 7/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.9541e-04 - mean_absolute_error: 0.0121 - val_loss: 0.1260 - val_mean_absolute_error: 0.2834
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.6171e-04 - mean_absolute_error: 0.0112 - val_loss: 0.1135 - val_mean_absolute_error: 0.2681
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.3403e-04 - mean_absolute_error: 0.0103 - val_loss: 0.1000 - val_mean_absolute_error: 0.2481
# Epoch 10/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2077e-04 - mean_absolute_error: 0.0099 - val_loss: 0.1027 - val_mean_absolute_error: 0.2539
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.1114e-04 - mean_absolute_error: 0.0095 - val_loss: 0.1064 - val_mean_absolute_error: 0.2607
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0489e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0970 - val_mean_absolute_error: 0.2455
# Epoch 13/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9416e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0938 - val_mean_absolute_error: 0.2410
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8997e-04 - mean_absolute_error: 0.0088 - val_loss: 0.1013 - val_mean_absolute_error: 0.2535
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8596e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0961 - val_mean_absolute_error: 0.2446
# Epoch 16/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8409e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0957 - val_mean_absolute_error: 0.2445
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0957 - mean_absolute_error: 0.2445
# 驗證集的MSE 0.24446316063404083
# 測試集的MSE 0.05271659046411514
# Epoch 1/50
# 67/67 [==============================] - 3s 11ms/step - loss: 0.0326 - mean_absolute_error: 0.1236 - val_loss: 1.5916 - val_mean_absolute_error: 1.1051
# Epoch 2/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0499 - val_loss: 0.4344 - val_mean_absolute_error: 0.5085
# Epoch 3/50
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0293 - val_loss: 0.3202 - val_mean_absolute_error: 0.4467
# Epoch 4/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0010 - mean_absolute_error: 0.0208 - val_loss: 0.2262 - val_mean_absolute_error: 0.3749
# Epoch 5/50
# 67/67 [==============================] - 0s 6ms/step - loss: 6.0480e-04 - mean_absolute_error: 0.0162 - val_loss: 0.1722 - val_mean_absolute_error: 0.3260
# Epoch 6/50
# 67/67 [==============================] - 0s 5ms/step - loss: 4.4890e-04 - mean_absolute_error: 0.0135 - val_loss: 0.1434 - val_mean_absolute_error: 0.2962
# Epoch 7/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.8103e-04 - mean_absolute_error: 0.0118 - val_loss: 0.1248 - val_mean_absolute_error: 0.2750
# Epoch 8/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.4562e-04 - mean_absolute_error: 0.0108 - val_loss: 0.1097 - val_mean_absolute_error: 0.2557
# Epoch 9/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.2678e-04 - mean_absolute_error: 0.0101 - val_loss: 0.1051 - val_mean_absolute_error: 0.2522
# Epoch 10/50
# 67/67 [==============================] - 0s 6ms/step - loss: 3.1486e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0971 - val_mean_absolute_error: 0.2399
# Epoch 11/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0579e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0952 - val_mean_absolute_error: 0.2389
# Epoch 12/50
# 67/67 [==============================] - 0s 5ms/step - loss: 3.0084e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0918 - val_mean_absolute_error: 0.2328
# Epoch 13/50
# 67/67 [==============================] - 0s 6ms/step - loss: 2.9421e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0966 - val_mean_absolute_error: 0.2418
# Epoch 14/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9344e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0925 - val_mean_absolute_error: 0.2353
# Epoch 15/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.9054e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0911 - val_mean_absolute_error: 0.2327
# Epoch 16/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8792e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0986 - val_mean_absolute_error: 0.2465
# Epoch 17/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8229e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0967 - val_mean_absolute_error: 0.2425
# Epoch 18/50
# 67/67 [==============================] - 0s 5ms/step - loss: 2.8242e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0965 - val_mean_absolute_error: 0.2425
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0965 - mean_absolute_error: 0.2425
# 驗證集的MSE 0.24252673983573914
# 測試集的MSE 0.053627438843250275
