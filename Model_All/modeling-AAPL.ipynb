# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('data/train.csv').drop('Date',axis=1)
val_df = pd.read_csv('data/val.csv').drop('Date',axis=1)
test_df = pd.read_csv('data/test.csv').drop('Date',axis=1)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (7503, 15) (2144, 15) (1045, 15)

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='Adj Close', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=1000):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline models

# %%
multi_window = DataWindow(input_width=7, label_width=7, shift=7, label_columns=['Adj Close'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 7, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 7, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index=column_indices['Adj Close'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 67/67 [==============================] - 0s 940us/step - loss: 2.2573 - mean_absolute_error: 0.8723

# %%
multi_window.plot(baseline_last)

plt.savefig('figures/CH18_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### Repeat last day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Adj Close'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 67/67 [==============================] - 0s 831us/step - loss: 2.2615 - mean_absolute_error: 0.8761

# %%
multi_window.plot(baseline_repeat)

plt.savefig('figures/CH18_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ## Linear model

# %%
label_index = column_indices['Adj Close']
num_features = train_df.shape[1]

linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0387 - val_loss: 0.0420 - val_mean_absolute_error: 0.1514
# Epoch 2/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 2.0251e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0265 - val_mean_absolute_error: 0.1170
# Epoch 3/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.9236e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0266 - val_mean_absolute_error: 0.1172
# Epoch 4/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.8668e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0262 - val_mean_absolute_error: 0.1162
# Epoch 5/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.8554e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0241 - val_mean_absolute_error: 0.1109
# Epoch 6/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.8115e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0227 - val_mean_absolute_error: 0.1074
# Epoch 7/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.8083e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0228 - val_mean_absolute_error: 0.1078
# Epoch 8/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.7921e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0260 - val_mean_absolute_error: 0.1158
# Epoch 9/1000
# 235/235 [==============================] - 0s 1ms/step - loss: 1.7853e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0228 - val_mean_absolute_error: 0.1076
# 67/67 [==============================] - 0s 820us/step - loss: 0.0228 - mean_absolute_error: 0.1076

# %%
multi_window.plot(linear)

plt.savefig('figures/CH18_F09_peixeiro.png', dpi=300)

# %% [markdown]
# ## Dense model

# %%
dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(dense, multi_window)

val_performance['Dense'] = dense.evaluate(multi_window.val)
performance['Dense'] = dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0196 - val_loss: 0.0576 - val_mean_absolute_error: 0.1754
# Epoch 2/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.8765e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0452 - val_mean_absolute_error: 0.1529
# Epoch 3/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.8090e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0447 - val_mean_absolute_error: 0.1524
# Epoch 4/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.7537e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0362 - val_mean_absolute_error: 0.1344
# Epoch 5/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 2.0510e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0346 - val_mean_absolute_error: 0.1316
# Epoch 6/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.9324e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0471 - val_mean_absolute_error: 0.1571
# Epoch 7/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.7774e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0651 - val_mean_absolute_error: 0.1896
# Epoch 8/1000
# 235/235 [==============================] - 0s 2ms/step - loss: 1.8446e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0377 - val_mean_absolute_error: 0.1378
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0377 - mean_absolute_error: 0.1378

# %% [markdown]
# ## LSTM model

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(lstm_model, multi_window)

val_performance['LSTM'] = lstm_model.evaluate(multi_window.val)
performance['LSTM'] = lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 235/235 [==============================] - 3s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0305 - val_loss: 2.6661 - val_mean_absolute_error: 1.2503
# Epoch 2/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 2.6082e-04 - mean_absolute_error: 0.0082 - val_loss: 2.3973 - val_mean_absolute_error: 1.1626
# Epoch 3/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8961e-04 - mean_absolute_error: 0.0067 - val_loss: 2.3648 - val_mean_absolute_error: 1.1489
# Epoch 4/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8726e-04 - mean_absolute_error: 0.0067 - val_loss: 2.3393 - val_mean_absolute_error: 1.1353
# Epoch 5/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7931e-04 - mean_absolute_error: 0.0063 - val_loss: 2.3330 - val_mean_absolute_error: 1.1327
# Epoch 6/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8270e-04 - mean_absolute_error: 0.0064 - val_loss: 2.3266 - val_mean_absolute_error: 1.1298
# Epoch 7/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8416e-04 - mean_absolute_error: 0.0064 - val_loss: 2.3379 - val_mean_absolute_error: 1.1363
# Epoch 8/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0063 - val_loss: 2.2508 - val_mean_absolute_error: 1.0962
# Epoch 9/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.9143e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2776 - val_mean_absolute_error: 1.1110
# Epoch 10/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8099e-04 - mean_absolute_error: 0.0064 - val_loss: 2.2235 - val_mean_absolute_error: 1.0883
# Epoch 11/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7791e-04 - mean_absolute_error: 0.0063 - val_loss: 2.2009 - val_mean_absolute_error: 1.0812
# Epoch 12/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8537e-04 - mean_absolute_error: 0.0066 - val_loss: 2.2270 - val_mean_absolute_error: 1.0971
# Epoch 13/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7494e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1992 - val_mean_absolute_error: 1.0878
# Epoch 14/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7649e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1295 - val_mean_absolute_error: 1.0584
# Epoch 15/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7629e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1254 - val_mean_absolute_error: 1.0609
# Epoch 16/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8114e-04 - mean_absolute_error: 0.0066 - val_loss: 2.0529 - val_mean_absolute_error: 1.0302
# Epoch 17/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7907e-04 - mean_absolute_error: 0.0064 - val_loss: 2.0945 - val_mean_absolute_error: 1.0541
# Epoch 18/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7329e-04 - mean_absolute_error: 0.0063 - val_loss: 2.0500 - val_mean_absolute_error: 1.0369
# Epoch 19/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7015e-04 - mean_absolute_error: 0.0061 - val_loss: 2.0573 - val_mean_absolute_error: 1.0446
# Epoch 20/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8539e-04 - mean_absolute_error: 0.0064 - val_loss: 2.0008 - val_mean_absolute_error: 1.0218
# Epoch 21/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7359e-04 - mean_absolute_error: 0.0061 - val_loss: 1.9344 - val_mean_absolute_error: 0.9927
# Epoch 22/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7168e-04 - mean_absolute_error: 0.0061 - val_loss: 1.9588 - val_mean_absolute_error: 1.0081
# Epoch 23/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7408e-04 - mean_absolute_error: 0.0064 - val_loss: 1.9301 - val_mean_absolute_error: 0.9982
# Epoch 24/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.8238e-04 - mean_absolute_error: 0.0066 - val_loss: 1.9057 - val_mean_absolute_error: 0.9905
# Epoch 25/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7219e-04 - mean_absolute_error: 0.0062 - val_loss: 1.8324 - val_mean_absolute_error: 0.9571
# Epoch 26/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6761e-04 - mean_absolute_error: 0.0061 - val_loss: 1.8964 - val_mean_absolute_error: 0.9924
# Epoch 27/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7399e-04 - mean_absolute_error: 0.0063 - val_loss: 1.7841 - val_mean_absolute_error: 0.9393
# Epoch 28/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7247e-04 - mean_absolute_error: 0.0063 - val_loss: 1.8918 - val_mean_absolute_error: 1.0004
# Epoch 29/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6957e-04 - mean_absolute_error: 0.0061 - val_loss: 1.8109 - val_mean_absolute_error: 0.9612
# Epoch 30/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7336e-04 - mean_absolute_error: 0.0064 - val_loss: 1.7724 - val_mean_absolute_error: 0.9437
# Epoch 31/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7244e-04 - mean_absolute_error: 0.0063 - val_loss: 1.7760 - val_mean_absolute_error: 0.9488
# Epoch 32/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7400e-04 - mean_absolute_error: 0.0062 - val_loss: 1.6751 - val_mean_absolute_error: 0.9000
# Epoch 33/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.7103e-04 - mean_absolute_error: 0.0062 - val_loss: 1.7153 - val_mean_absolute_error: 0.9236
# Epoch 34/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6989e-04 - mean_absolute_error: 0.0062 - val_loss: 1.6906 - val_mean_absolute_error: 0.9138
# Epoch 35/1000
# 235/235 [==============================] - 1s 3ms/step - loss: 1.6958e-04 - mean_absolute_error: 0.0061 - val_loss: 1.7156 - val_mean_absolute_error: 0.9296
# 67/67 [==============================] - 0s 1ms/step - loss: 1.7156 - mean_absolute_error: 0.9296

# %%
multi_window.plot(lstm_model)

plt.savefig('figures/CH18_F10_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 7
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=7, label_columns=['Adj Close'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 234/234 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0186 - val_loss: 0.0600 - val_mean_absolute_error: 0.1827
# Epoch 2/1000
# 234/234 [==============================] - 0s 2ms/step - loss: 1.9744e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0351 - val_mean_absolute_error: 0.1336
# Epoch 3/1000
# 234/234 [==============================] - 0s 1ms/step - loss: 1.9166e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0726 - val_mean_absolute_error: 0.2032
# Epoch 4/1000
# 234/234 [==============================] - 0s 1ms/step - loss: 1.9211e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0470 - val_mean_absolute_error: 0.1564
# Epoch 5/1000
# 234/234 [==============================] - 0s 2ms/step - loss: 2.0018e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0448 - val_mean_absolute_error: 0.1521
# 67/67 [==============================] - 0s 968us/step - loss: 0.0448 - mean_absolute_error: 0.1521

# %%
cnn_multi_window.plot(cnn_model)

plt.savefig('figures/CH18_F11_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN + LSTM model

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 234/234 [==============================] - 3s 5ms/step - loss: 0.0047 - mean_absolute_error: 0.0258 - val_loss: 3.6603 - val_mean_absolute_error: 1.5315
# Epoch 2/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.6124e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4007 - val_mean_absolute_error: 1.4491
# Epoch 3/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.3457e-04 - mean_absolute_error: 0.0074 - val_loss: 3.2836 - val_mean_absolute_error: 1.4113
# Epoch 4/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.4073e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2203 - val_mean_absolute_error: 1.3914
# Epoch 5/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.1049e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0972 - val_mean_absolute_error: 1.3442
# Epoch 6/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0697e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0713 - val_mean_absolute_error: 1.3405
# Epoch 7/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 2.0617e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0281 - val_mean_absolute_error: 1.3290
# Epoch 8/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0729e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9553 - val_mean_absolute_error: 1.3027
# Epoch 9/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0522e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9264 - val_mean_absolute_error: 1.2982
# Epoch 10/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0801e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8437 - val_mean_absolute_error: 1.2677
# Epoch 11/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.3548e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8140 - val_mean_absolute_error: 1.2623
# Epoch 12/1000
# 234/234 [==============================] - 1s 5ms/step - loss: 1.9660e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7835 - val_mean_absolute_error: 1.2556
# Epoch 13/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9081e-04 - mean_absolute_error: 0.0065 - val_loss: 2.7375 - val_mean_absolute_error: 1.2431
# Epoch 14/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.1712e-04 - mean_absolute_error: 0.0074 - val_loss: 2.6961 - val_mean_absolute_error: 1.2288
# Epoch 15/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8522e-04 - mean_absolute_error: 0.0067 - val_loss: 2.6343 - val_mean_absolute_error: 1.2049
# Epoch 16/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9905e-04 - mean_absolute_error: 0.0069 - val_loss: 2.5826 - val_mean_absolute_error: 1.1874
# Epoch 17/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9449e-04 - mean_absolute_error: 0.0067 - val_loss: 2.5831 - val_mean_absolute_error: 1.1952
# Epoch 18/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8556e-04 - mean_absolute_error: 0.0066 - val_loss: 2.5288 - val_mean_absolute_error: 1.1746
# Epoch 19/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8412e-04 - mean_absolute_error: 0.0065 - val_loss: 2.5088 - val_mean_absolute_error: 1.1722
# Epoch 20/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.7751e-04 - mean_absolute_error: 0.0063 - val_loss: 2.4614 - val_mean_absolute_error: 1.1551
# Epoch 21/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8121e-04 - mean_absolute_error: 0.0064 - val_loss: 2.3852 - val_mean_absolute_error: 1.1233
# Epoch 22/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0382e-04 - mean_absolute_error: 0.0069 - val_loss: 2.3661 - val_mean_absolute_error: 1.1210
# Epoch 23/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.7074e-04 - mean_absolute_error: 0.0062 - val_loss: 2.3228 - val_mean_absolute_error: 1.1026
# Epoch 24/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7120e-04 - mean_absolute_error: 0.0062 - val_loss: 2.3716 - val_mean_absolute_error: 1.1347
# Epoch 25/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8582e-04 - mean_absolute_error: 0.0068 - val_loss: 2.2903 - val_mean_absolute_error: 1.0956
# Epoch 26/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7799e-04 - mean_absolute_error: 0.0064 - val_loss: 2.2686 - val_mean_absolute_error: 1.0892
# Epoch 27/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7807e-04 - mean_absolute_error: 0.0065 - val_loss: 2.2352 - val_mean_absolute_error: 1.0765
# Epoch 28/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.7214e-04 - mean_absolute_error: 0.0062 - val_loss: 2.2127 - val_mean_absolute_error: 1.0694
# Epoch 29/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8492e-04 - mean_absolute_error: 0.0067 - val_loss: 2.2233 - val_mean_absolute_error: 1.0800
# Epoch 30/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8632e-04 - mean_absolute_error: 0.0064 - val_loss: 2.1856 - val_mean_absolute_error: 1.0659
# Epoch 31/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.6976e-04 - mean_absolute_error: 0.0061 - val_loss: 2.1619 - val_mean_absolute_error: 1.0579
# Epoch 32/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.6593e-04 - mean_absolute_error: 0.0061 - val_loss: 2.1799 - val_mean_absolute_error: 1.0731
# Epoch 33/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7332e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1038 - val_mean_absolute_error: 1.0357
# Epoch 34/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7885e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1336 - val_mean_absolute_error: 1.0560
# Epoch 35/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8294e-04 - mean_absolute_error: 0.0065 - val_loss: 2.0767 - val_mean_absolute_error: 1.0295
# Epoch 36/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.7363e-04 - mean_absolute_error: 0.0062 - val_loss: 2.1051 - val_mean_absolute_error: 1.0489
# Epoch 37/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7399e-04 - mean_absolute_error: 0.0063 - val_loss: 2.0635 - val_mean_absolute_error: 1.0288
# Epoch 38/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.6145e-04 - mean_absolute_error: 0.0061 - val_loss: 2.0440 - val_mean_absolute_error: 1.0212
# Epoch 39/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.6029e-04 - mean_absolute_error: 0.0061 - val_loss: 2.0321 - val_mean_absolute_error: 1.0145
# Epoch 40/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7821e-04 - mean_absolute_error: 0.0065 - val_loss: 2.0520 - val_mean_absolute_error: 1.0277
# Epoch 41/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.6207e-04 - mean_absolute_error: 0.0063 - val_loss: 2.0119 - val_mean_absolute_error: 1.0100
# Epoch 42/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7777e-04 - mean_absolute_error: 0.0065 - val_loss: 2.0398 - val_mean_absolute_error: 1.0243
# Epoch 43/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.6329e-04 - mean_absolute_error: 0.0061 - val_loss: 2.0242 - val_mean_absolute_error: 1.0178
# Epoch 44/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.5650e-04 - mean_absolute_error: 0.0058 - val_loss: 1.9941 - val_mean_absolute_error: 1.0037
# Epoch 45/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.6164e-04 - mean_absolute_error: 0.0062 - val_loss: 2.0399 - val_mean_absolute_error: 1.0302
# Epoch 46/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.5952e-04 - mean_absolute_error: 0.0062 - val_loss: 1.9954 - val_mean_absolute_error: 1.0058
# Epoch 47/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.5871e-04 - mean_absolute_error: 0.0060 - val_loss: 2.0629 - val_mean_absolute_error: 1.0418
# 67/67 [==============================] - 0s 2ms/step - loss: 2.0629 - mean_absolute_error: 1.0418

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.savefig('figures/CH18_F12_peixeiro.png', dpi=300)

# %% [markdown]
# ## Autoregressive LSTM

# %%
class AutoRegressive(Model):
    def __init__(self, units, out_steps):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = LSTMCell(units)
        self.lstm_rnn = RNN(self.lstm_cell, return_state=True)
        self.dense = Dense(train_df.shape[1])
        
    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        prediction = self.dense(x)
                
        return prediction, state
    
    def call(self, inputs, training=None):
        predictions = []
        prediction, state = self.warmup(inputs)
        
        predictions.append(prediction)
        
        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            
            prediction = self.dense(x)
            predictions.append(prediction)
        
        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        
        return predictions

# %%
AR_LSTM = AutoRegressive(units=32, out_steps=7)

history = compile_and_fit(AR_LSTM, multi_window)

val_performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.val)
performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 235/235 [==============================] - 3s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0237 - val_loss: 3.6483 - val_mean_absolute_error: 1.5242
# Epoch 2/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 2.6376e-04 - mean_absolute_error: 0.0092 - val_loss: 3.4275 - val_mean_absolute_error: 1.4543
# Epoch 3/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2698e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3580 - val_mean_absolute_error: 1.4346
# Epoch 4/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8946e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3484 - val_mean_absolute_error: 1.4374
# Epoch 5/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0070e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2295 - val_mean_absolute_error: 1.3893
# Epoch 6/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1208e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3310 - val_mean_absolute_error: 1.4299
# Epoch 7/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5744e-04 - mean_absolute_error: 0.0064 - val_loss: 3.2199 - val_mean_absolute_error: 1.3890
# Epoch 8/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5679e-04 - mean_absolute_error: 0.0065 - val_loss: 3.2596 - val_mean_absolute_error: 1.4049
# Epoch 9/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5796e-04 - mean_absolute_error: 0.0067 - val_loss: 3.3066 - val_mean_absolute_error: 1.4283
# Epoch 10/1000
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5410e-04 - mean_absolute_error: 0.0062 - val_loss: 3.2896 - val_mean_absolute_error: 1.4208
# 67/67 [==============================] - 0s 2ms/step - loss: 3.2896 - mean_absolute_error: 1.4208

# %%
multi_window.plot(AR_LSTM)

plt.savefig('figures/CH18_F13_peixeiro.png', dpi=300)

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 234/234 [==============================] - 3s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0241 - val_loss: 3.6770 - val_mean_absolute_error: 1.5199
# Epoch 2/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.5267e-04 - mean_absolute_error: 0.0079 - val_loss: 3.4821 - val_mean_absolute_error: 1.4635
# Epoch 3/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.1695e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2963 - val_mean_absolute_error: 1.4027
# Epoch 4/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.1740e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2209 - val_mean_absolute_error: 1.3848
# Epoch 5/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9697e-04 - mean_absolute_error: 0.0066 - val_loss: 3.1181 - val_mean_absolute_error: 1.3518
# Epoch 6/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9954e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0325 - val_mean_absolute_error: 1.3250
# Epoch 7/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.8570e-04 - mean_absolute_error: 0.0064 - val_loss: 2.9656 - val_mean_absolute_error: 1.3085
# Epoch 8/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 2.0059e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8772 - val_mean_absolute_error: 1.2767
# Epoch 9/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8570e-04 - mean_absolute_error: 0.0066 - val_loss: 2.8485 - val_mean_absolute_error: 1.2741
# Epoch 10/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9708e-04 - mean_absolute_error: 0.0067 - val_loss: 2.7484 - val_mean_absolute_error: 1.2355
# Epoch 11/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8336e-04 - mean_absolute_error: 0.0066 - val_loss: 2.7132 - val_mean_absolute_error: 1.2292
# Epoch 12/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8830e-04 - mean_absolute_error: 0.0067 - val_loss: 2.7232 - val_mean_absolute_error: 1.2415
# Epoch 13/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8214e-04 - mean_absolute_error: 0.0067 - val_loss: 2.6474 - val_mean_absolute_error: 1.2148
# Epoch 14/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8285e-04 - mean_absolute_error: 0.0063 - val_loss: 2.5915 - val_mean_absolute_error: 1.1974
# Epoch 15/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9465e-04 - mean_absolute_error: 0.0067 - val_loss: 2.6198 - val_mean_absolute_error: 1.2230
# Epoch 16/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8651e-04 - mean_absolute_error: 0.0067 - val_loss: 2.5445 - val_mean_absolute_error: 1.1890
# Epoch 17/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8712e-04 - mean_absolute_error: 0.0065 - val_loss: 2.4653 - val_mean_absolute_error: 1.1583
# Epoch 18/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8155e-04 - mean_absolute_error: 0.0066 - val_loss: 2.3743 - val_mean_absolute_error: 1.1169
# Epoch 19/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9242e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4202 - val_mean_absolute_error: 1.1453
# Epoch 20/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.9574e-04 - mean_absolute_error: 0.0069 - val_loss: 2.3669 - val_mean_absolute_error: 1.1212
# Epoch 21/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.6837e-04 - mean_absolute_error: 0.0061 - val_loss: 2.3633 - val_mean_absolute_error: 1.1245
# Epoch 22/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7552e-04 - mean_absolute_error: 0.0064 - val_loss: 2.3440 - val_mean_absolute_error: 1.1185
# Epoch 23/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.8729e-04 - mean_absolute_error: 0.0066 - val_loss: 2.2557 - val_mean_absolute_error: 1.0753
# Epoch 24/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.8010e-04 - mean_absolute_error: 0.0063 - val_loss: 2.2907 - val_mean_absolute_error: 1.0940
# Epoch 25/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.7879e-04 - mean_absolute_error: 0.0063 - val_loss: 2.2449 - val_mean_absolute_error: 1.0725
# Epoch 26/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.7500e-04 - mean_absolute_error: 0.0064 - val_loss: 2.2884 - val_mean_absolute_error: 1.0969
# Epoch 27/1000
# 234/234 [==============================] - 1s 3ms/step - loss: 1.6489e-04 - mean_absolute_error: 0.0061 - val_loss: 2.3125 - val_mean_absolute_error: 1.1129
# Epoch 28/1000
# 234/234 [==============================] - 1s 4ms/step - loss: 1.6862e-04 - mean_absolute_error: 0.0064 - val_loss: 2.3018 - val_mean_absolute_error: 1.1092
# 67/67 [==============================] - 0s 1ms/step - loss: 2.3018 - mean_absolute_error: 1.1092

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')

# plt.ylim(0, 0.33)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH18_F14_peixeiro.png', dpi=300)
