# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('data/train.csv').drop('Date',axis=1)
val_df = pd.read_csv('data/val.csv').drop('Date',axis=1)
test_df = pd.read_csv('data/test.csv').drop('Date',axis=1)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (1435, 15) (410, 15) (178, 15)

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='Adj Close', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=1000):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline models

# %%
multi_window = DataWindow(input_width=7, label_width=7, shift=7, label_columns=['Adj Close'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 7, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 7, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index=column_indices['Adj Close'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0562 - mean_absolute_error: 0.1833

# %%
multi_window.plot(baseline_last)

plt.savefig('figures/CH18_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### Repeat last day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Adj Close'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 13/13 [==============================] - 0s 938us/step - loss: 0.0562 - mean_absolute_error: 0.1833

# %%
multi_window.plot(baseline_repeat)

plt.savefig('figures/CH18_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ## Linear model

# %%
label_index = column_indices['Adj Close']
num_features = train_df.shape[1]

linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.1747 - val_loss: 0.0021 - val_mean_absolute_error: 0.0430
# Epoch 2/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0348 - val_loss: 3.9658e-04 - val_mean_absolute_error: 0.0163
# Epoch 3/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0308 - val_loss: 3.0144e-04 - val_mean_absolute_error: 0.0145
# Epoch 4/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 2.7876e-04 - val_mean_absolute_error: 0.0139
# Epoch 5/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0298 - val_loss: 2.5050e-04 - val_mean_absolute_error: 0.0131
# Epoch 6/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0293 - val_loss: 2.2479e-04 - val_mean_absolute_error: 0.0124
# Epoch 7/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0290 - val_loss: 1.9795e-04 - val_mean_absolute_error: 0.0116
# Epoch 8/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0286 - val_loss: 1.8039e-04 - val_mean_absolute_error: 0.0110
# Epoch 9/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0281 - val_loss: 1.6416e-04 - val_mean_absolute_error: 0.0104
# Epoch 10/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0279 - val_loss: 1.5000e-04 - val_mean_absolute_error: 0.0099
# Epoch 11/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0276 - val_loss: 1.4035e-04 - val_mean_absolute_error: 0.0095
# Epoch 12/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0273 - val_loss: 1.2787e-04 - val_mean_absolute_error: 0.0090
# Epoch 13/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0271 - val_loss: 1.3092e-04 - val_mean_absolute_error: 0.0089
# Epoch 14/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0269 - val_loss: 1.1797e-04 - val_mean_absolute_error: 0.0084
# Epoch 15/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0267 - val_loss: 1.1853e-04 - val_mean_absolute_error: 0.0083
# Epoch 16/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0265 - val_loss: 1.1353e-04 - val_mean_absolute_error: 0.0081
# Epoch 17/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0263 - val_loss: 1.1808e-04 - val_mean_absolute_error: 0.0082
# Epoch 18/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0262 - val_loss: 1.1711e-04 - val_mean_absolute_error: 0.0081
# Epoch 19/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0261 - val_loss: 1.0380e-04 - val_mean_absolute_error: 0.0075
# Epoch 20/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0259 - val_loss: 1.1073e-04 - val_mean_absolute_error: 0.0078
# Epoch 21/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0258 - val_loss: 1.1409e-04 - val_mean_absolute_error: 0.0079
# Epoch 22/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0257 - val_loss: 1.1069e-04 - val_mean_absolute_error: 0.0077
# 13/13 [==============================] - 0s 899us/step - loss: 1.1069e-04 - mean_absolute_error: 0.0077

# %%
multi_window.plot(linear)

plt.savefig('figures/CH18_F09_peixeiro.png', dpi=300)

# %% [markdown]
# ## Dense model

# %%
dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(dense, multi_window)

val_performance['Dense'] = dense.evaluate(multi_window.val)
performance['Dense'] = dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 1s 5ms/step - loss: 0.0289 - mean_absolute_error: 0.1301 - val_loss: 0.0010 - val_mean_absolute_error: 0.0291
# Epoch 2/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0295 - val_loss: 1.1083e-04 - val_mean_absolute_error: 0.0080
# Epoch 3/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0254 - val_loss: 1.2997e-04 - val_mean_absolute_error: 0.0078
# Epoch 4/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0249 - val_loss: 1.2939e-04 - val_mean_absolute_error: 0.0080
# Epoch 5/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0249 - val_loss: 1.1349e-04 - val_mean_absolute_error: 0.0071
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1349e-04 - mean_absolute_error: 0.0071

# %% [markdown]
# ## LSTM model

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(lstm_model, multi_window)

val_performance['LSTM'] = lstm_model.evaluate(multi_window.val)
performance['LSTM'] = lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 11ms/step - loss: 0.0399 - mean_absolute_error: 0.1700 - val_loss: 0.0083 - val_mean_absolute_error: 0.0693
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0088 - mean_absolute_error: 0.0694 - val_loss: 0.0038 - val_mean_absolute_error: 0.0452
# Epoch 3/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0479 - val_loss: 0.0015 - val_mean_absolute_error: 0.0257
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0364 - val_loss: 7.3004e-04 - val_mean_absolute_error: 0.0208
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0329 - val_loss: 4.4603e-04 - val_mean_absolute_error: 0.0169
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 2.7721e-04 - val_mean_absolute_error: 0.0133
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0283 - val_loss: 2.3699e-04 - val_mean_absolute_error: 0.0123
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0269 - val_loss: 1.4481e-04 - val_mean_absolute_error: 0.0093
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0263 - val_loss: 9.8420e-05 - val_mean_absolute_error: 0.0076
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 7.5075e-05 - val_mean_absolute_error: 0.0066
# Epoch 11/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 6.8369e-05 - val_mean_absolute_error: 0.0062
# Epoch 12/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0254 - val_loss: 6.3465e-05 - val_mean_absolute_error: 0.0061
# Epoch 13/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0255 - val_loss: 6.1698e-05 - val_mean_absolute_error: 0.0061
# Epoch 14/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0252 - val_loss: 6.0195e-05 - val_mean_absolute_error: 0.0060
# Epoch 15/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0252 - val_loss: 7.9261e-05 - val_mean_absolute_error: 0.0067
# Epoch 16/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0252 - val_loss: 6.3057e-05 - val_mean_absolute_error: 0.0058
# Epoch 17/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0255 - val_loss: 5.7758e-05 - val_mean_absolute_error: 0.0058
# Epoch 18/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0257 - val_loss: 6.2025e-05 - val_mean_absolute_error: 0.0058
# Epoch 19/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0263 - val_loss: 7.2812e-05 - val_mean_absolute_error: 0.0064
# Epoch 20/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0251 - val_loss: 6.5789e-05 - val_mean_absolute_error: 0.0060
# 13/13 [==============================] - 0s 1ms/step - loss: 6.5789e-05 - mean_absolute_error: 0.0060

# %%
multi_window.plot(lstm_model)

plt.savefig('figures/CH18_F10_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 7
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=7, label_columns=['Adj Close'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 1s 4ms/step - loss: 0.0330 - mean_absolute_error: 0.1423 - val_loss: 0.0010 - val_mean_absolute_error: 0.0282
# Epoch 2/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0323 - val_loss: 2.5592e-04 - val_mean_absolute_error: 0.0135
# Epoch 3/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0280 - val_loss: 1.1138e-04 - val_mean_absolute_error: 0.0090
# Epoch 4/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0266 - val_loss: 1.1226e-04 - val_mean_absolute_error: 0.0083
# Epoch 5/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0262 - val_loss: 5.3834e-05 - val_mean_absolute_error: 0.0061
# Epoch 6/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 5.3431e-05 - val_mean_absolute_error: 0.0055
# Epoch 7/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0251 - val_loss: 5.9255e-05 - val_mean_absolute_error: 0.0057
# Epoch 8/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0250 - val_loss: 9.0088e-05 - val_mean_absolute_error: 0.0072
# Epoch 9/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0250 - val_loss: 5.6536e-05 - val_mean_absolute_error: 0.0055
# 13/13 [==============================] - 0s 914us/step - loss: 5.6536e-05 - mean_absolute_error: 0.0055

# %%
cnn_multi_window.plot(cnn_model)

plt.savefig('figures/CH18_F11_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN + LSTM model

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 11ms/step - loss: 0.0347 - mean_absolute_error: 0.1514 - val_loss: 0.0045 - val_mean_absolute_error: 0.0446
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0053 - mean_absolute_error: 0.0518 - val_loss: 0.0015 - val_mean_absolute_error: 0.0336
# Epoch 3/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0356 - val_loss: 3.1892e-04 - val_mean_absolute_error: 0.0152
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0289 - val_loss: 1.2070e-04 - val_mean_absolute_error: 0.0087
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0276 - val_loss: 1.0781e-04 - val_mean_absolute_error: 0.0082
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0264 - val_loss: 1.1452e-04 - val_mean_absolute_error: 0.0087
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0260 - val_loss: 5.6845e-05 - val_mean_absolute_error: 0.0060
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 4.0587e-05 - val_mean_absolute_error: 0.0051
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0257 - val_loss: 4.0491e-05 - val_mean_absolute_error: 0.0051
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0259 - val_loss: 3.8590e-05 - val_mean_absolute_error: 0.0049
# Epoch 11/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0259 - val_loss: 6.1577e-05 - val_mean_absolute_error: 0.0066
# Epoch 12/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0255 - val_loss: 4.4647e-05 - val_mean_absolute_error: 0.0055
# Epoch 13/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0252 - val_loss: 5.7457e-05 - val_mean_absolute_error: 0.0064
# 13/13 [==============================] - 0s 2ms/step - loss: 5.7457e-05 - mean_absolute_error: 0.0064

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.savefig('figures/CH18_F12_peixeiro.png', dpi=300)

# %% [markdown]
# ## Autoregressive LSTM

# %%
class AutoRegressive(Model):
    def __init__(self, units, out_steps):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = LSTMCell(units)
        self.lstm_rnn = RNN(self.lstm_cell, return_state=True)
        self.dense = Dense(train_df.shape[1])
        
    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        prediction = self.dense(x)
                
        return prediction, state
    
    def call(self, inputs, training=None):
        predictions = []
        prediction, state = self.warmup(inputs)
        
        predictions.append(prediction)
        
        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            
            prediction = self.dense(x)
            predictions.append(prediction)
        
        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        
        return predictions

# %%
AR_LSTM = AutoRegressive(units=32, out_steps=7)

history = compile_and_fit(AR_LSTM, multi_window)

val_performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.val)
performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 9ms/step - loss: 0.0255 - mean_absolute_error: 0.1104 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0325 - val_loss: 3.9100e-04 - val_mean_absolute_error: 0.0147
# Epoch 3/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0292 - val_loss: 3.7204e-04 - val_mean_absolute_error: 0.0150
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0284 - val_loss: 2.5291e-04 - val_mean_absolute_error: 0.0121
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0275 - val_loss: 2.4144e-04 - val_mean_absolute_error: 0.0120
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0268 - val_loss: 2.0899e-04 - val_mean_absolute_error: 0.0110
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0264 - val_loss: 2.6715e-04 - val_mean_absolute_error: 0.0129
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0265 - val_loss: 1.9724e-04 - val_mean_absolute_error: 0.0106
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0256 - val_loss: 1.7409e-04 - val_mean_absolute_error: 0.0102
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 1.8383e-04 - val_mean_absolute_error: 0.0103
# Epoch 11/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0254 - val_loss: 1.4799e-04 - val_mean_absolute_error: 0.0092
# Epoch 12/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0254 - val_loss: 1.4457e-04 - val_mean_absolute_error: 0.0090
# Epoch 13/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0253 - val_loss: 1.4336e-04 - val_mean_absolute_error: 0.0091
# Epoch 14/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0253 - val_loss: 1.5992e-04 - val_mean_absolute_error: 0.0094
# Epoch 15/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0251 - val_loss: 1.5795e-04 - val_mean_absolute_error: 0.0094
# Epoch 16/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0253 - val_loss: 1.3471e-04 - val_mean_absolute_error: 0.0090
# Epoch 17/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 1.2677e-04 - val_mean_absolute_error: 0.0085
# Epoch 18/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0251 - val_loss: 1.2544e-04 - val_mean_absolute_error: 0.0086
# Epoch 19/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 1.2338e-04 - val_mean_absolute_error: 0.0083
# Epoch 20/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 1.6641e-04 - val_mean_absolute_error: 0.0105
# Epoch 21/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 1.2946e-04 - val_mean_absolute_error: 0.0085
# Epoch 22/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 1.3341e-04 - val_mean_absolute_error: 0.0091
# 13/13 [==============================] - 0s 2ms/step - loss: 1.3341e-04 - mean_absolute_error: 0.0091

# %%
multi_window.plot(AR_LSTM)

plt.savefig('figures/CH18_F13_peixeiro.png', dpi=300)

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 11ms/step - loss: 0.0349 - mean_absolute_error: 0.1527 - val_loss: 0.0047 - val_mean_absolute_error: 0.0465
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0531 - val_loss: 0.0019 - val_mean_absolute_error: 0.0375
# Epoch 3/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0385 - val_loss: 4.6916e-04 - val_mean_absolute_error: 0.0194
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0294 - val_loss: 9.7449e-05 - val_mean_absolute_error: 0.0078
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0264 - val_loss: 9.9557e-05 - val_mean_absolute_error: 0.0079
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0259 - val_loss: 4.3955e-05 - val_mean_absolute_error: 0.0051
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0257 - val_loss: 8.0566e-05 - val_mean_absolute_error: 0.0072
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0266 - val_loss: 1.6758e-04 - val_mean_absolute_error: 0.0114
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0259 - val_loss: 3.8817e-05 - val_mean_absolute_error: 0.0048
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0257 - val_loss: 7.9703e-05 - val_mean_absolute_error: 0.0076
# Epoch 11/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0256 - val_loss: 9.4657e-05 - val_mean_absolute_error: 0.0081
# Epoch 12/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0255 - val_loss: 6.4375e-05 - val_mean_absolute_error: 0.0064
# 13/13 [==============================] - 0s 2ms/step - loss: 6.4375e-05 - mean_absolute_error: 0.0064

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')

# plt.ylim(0, 0.33)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH18_F14_peixeiro.png', dpi=300)
