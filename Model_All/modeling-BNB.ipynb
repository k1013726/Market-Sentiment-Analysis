# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('data/train.csv').drop('Date',axis=1)
val_df = pd.read_csv('data/val.csv').drop('Date',axis=1)
test_df = pd.read_csv('data/test.csv').drop('Date',axis=1)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (1435, 15) (410, 15) (178, 15)

# %% [markdown]
# ## `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='Adj Close', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=1000):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Baseline models

# %%
multi_window = DataWindow(input_width=7, label_width=7, shift=7, label_columns=['Adj Close'])

# %% [markdown]
# ### Repeat last value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 7, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 7, 1])

# %%
baseline_last = MultiStepLastBaseline(label_index=column_indices['Adj Close'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(multi_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0451 - mean_absolute_error: 0.1363

# %%
multi_window.plot(baseline_last)

plt.savefig('figures/CH18_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### Repeat last day

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
baseline_repeat = RepeatBaseline(label_index=column_indices['Adj Close'])

baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

val_performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.val)
performance['Baseline - Repeat'] = baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 13/13 [==============================] - 0s 914us/step - loss: 0.0457 - mean_absolute_error: 0.1398

# %%
multi_window.plot(baseline_repeat)

plt.savefig('figures/CH18_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ## Linear model

# %%
label_index = column_indices['Adj Close']
num_features = train_df.shape[1]

linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(linear, multi_window)

val_performance['Linear'] = linear.evaluate(multi_window.val)
performance['Linear'] = linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1030 - val_loss: 0.0488 - val_mean_absolute_error: 0.2033
# Epoch 2/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0117 - mean_absolute_error: 0.0868 - val_loss: 0.0107 - val_mean_absolute_error: 0.0892
# Epoch 3/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0529 - val_loss: 0.0032 - val_mean_absolute_error: 0.0459
# Epoch 4/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0335 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 5/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0251 - val_loss: 0.0025 - val_mean_absolute_error: 0.0371
# Epoch 6/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0221 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 7/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0204 - val_loss: 0.0028 - val_mean_absolute_error: 0.0402
# 13/13 [==============================] - 0s 991us/step - loss: 0.0028 - mean_absolute_error: 0.0402

# %%
multi_window.plot(linear)

plt.savefig('figures/CH18_F09_peixeiro.png', dpi=300)

# %% [markdown]
# ## Dense model

# %%
dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(dense, multi_window)

val_performance['Dense'] = dense.evaluate(multi_window.val)
performance['Dense'] = dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 1s 5ms/step - loss: 0.0234 - mean_absolute_error: 0.0875 - val_loss: 0.0036 - val_mean_absolute_error: 0.0459
# Epoch 2/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0231 - val_loss: 0.0030 - val_mean_absolute_error: 0.0422
# Epoch 3/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0201 - val_loss: 0.0037 - val_mean_absolute_error: 0.0477
# Epoch 4/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0020 - mean_absolute_error: 0.0188 - val_loss: 0.0052 - val_mean_absolute_error: 0.0582
# Epoch 5/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0176 - val_loss: 0.0038 - val_mean_absolute_error: 0.0492
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0492

# %% [markdown]
# ## LSTM model

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(lstm_model, multi_window)

val_performance['LSTM'] = lstm_model.evaluate(multi_window.val)
performance['LSTM'] = lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 12ms/step - loss: 0.0357 - mean_absolute_error: 0.1017 - val_loss: 0.0469 - val_mean_absolute_error: 0.1804
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0082 - mean_absolute_error: 0.0418 - val_loss: 0.0188 - val_mean_absolute_error: 0.1068
# Epoch 3/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0336 - val_loss: 0.0136 - val_mean_absolute_error: 0.0992
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0035 - mean_absolute_error: 0.0296 - val_loss: 0.0070 - val_mean_absolute_error: 0.0669
# Epoch 5/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0242 - val_loss: 0.0053 - val_mean_absolute_error: 0.0592
# Epoch 6/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0212 - val_loss: 0.0050 - val_mean_absolute_error: 0.0578
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0195 - val_loss: 0.0054 - val_mean_absolute_error: 0.0603
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0190 - val_loss: 0.0039 - val_mean_absolute_error: 0.0489
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0184 - val_loss: 0.0039 - val_mean_absolute_error: 0.0493
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0186 - val_loss: 0.0040 - val_mean_absolute_error: 0.0492
# Epoch 11/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0183 - val_loss: 0.0052 - val_mean_absolute_error: 0.0588
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0588

# %%
multi_window.plot(lstm_model)

plt.savefig('figures/CH18_F10_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 7
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

cnn_multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=7, label_columns=['Adj Close'])

# %%
cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_model, cnn_multi_window)

val_performance['CNN'] = cnn_model.evaluate(cnn_multi_window.val)
performance['CNN'] = cnn_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 1s 6ms/step - loss: 0.0323 - mean_absolute_error: 0.1058 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 2/1000
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0249 - val_loss: 0.0028 - val_mean_absolute_error: 0.0414
# Epoch 3/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0200 - val_loss: 0.0029 - val_mean_absolute_error: 0.0420
# Epoch 4/1000
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0192 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0444

# %%
cnn_multi_window.plot(cnn_model)

plt.savefig('figures/CH18_F11_peixeiro.png', dpi=300)

# %% [markdown]
# ## CNN + LSTM model

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 3s 12ms/step - loss: 0.0338 - mean_absolute_error: 0.1047 - val_loss: 0.0313 - val_mean_absolute_error: 0.1444
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0056 - mean_absolute_error: 0.0346 - val_loss: 0.0093 - val_mean_absolute_error: 0.0775
# Epoch 3/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0259 - val_loss: 0.0074 - val_mean_absolute_error: 0.0714
# Epoch 4/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0237 - val_loss: 0.0054 - val_mean_absolute_error: 0.0591
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0220 - val_loss: 0.0045 - val_mean_absolute_error: 0.0535
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0221 - val_loss: 0.0042 - val_mean_absolute_error: 0.0517
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0209 - val_loss: 0.0074 - val_mean_absolute_error: 0.0657
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0215 - val_loss: 0.0050 - val_mean_absolute_error: 0.0572
# Epoch 9/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0197 - val_loss: 0.0050 - val_mean_absolute_error: 0.0569
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0569

# %%
cnn_multi_window.plot(cnn_lstm_model)

plt.savefig('figures/CH18_F12_peixeiro.png', dpi=300)

# %% [markdown]
# ## Autoregressive LSTM

# %%
class AutoRegressive(Model):
    def __init__(self, units, out_steps):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = LSTMCell(units)
        self.lstm_rnn = RNN(self.lstm_cell, return_state=True)
        self.dense = Dense(train_df.shape[1])
        
    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        prediction = self.dense(x)
                
        return prediction, state
    
    def call(self, inputs, training=None):
        predictions = []
        prediction, state = self.warmup(inputs)
        
        predictions.append(prediction)
        
        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            
            prediction = self.dense(x)
            predictions.append(prediction)
        
        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        
        return predictions

# %%
AR_LSTM = AutoRegressive(units=32, out_steps=7)

history = compile_and_fit(AR_LSTM, multi_window)

val_performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.val)
performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 2s 11ms/step - loss: 0.0345 - mean_absolute_error: 0.0983 - val_loss: 0.0163 - val_mean_absolute_error: 0.1045
# Epoch 2/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0359 - val_loss: 0.0076 - val_mean_absolute_error: 0.0679
# Epoch 3/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0288 - val_loss: 0.0064 - val_mean_absolute_error: 0.0630
# Epoch 4/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0246 - val_loss: 0.0046 - val_mean_absolute_error: 0.0521
# Epoch 5/1000
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0223 - val_loss: 0.0059 - val_mean_absolute_error: 0.0568
# Epoch 6/1000
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0018 - mean_absolute_error: 0.0215 - val_loss: 0.0049 - val_mean_absolute_error: 0.0551
# Epoch 7/1000
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0204 - val_loss: 0.0042 - val_mean_absolute_error: 0.0493
# Epoch 8/1000
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0194 - val_loss: 0.0044 - val_mean_absolute_error: 0.0496
# Epoch 9/1000
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0187 - val_loss: 0.0045 - val_mean_absolute_error: 0.0524
# Epoch 10/1000
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0186 - val_loss: 0.0047 - val_mean_absolute_error: 0.0502
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0502

# %%
multi_window.plot(AR_LSTM)

plt.savefig('figures/CH18_F13_peixeiro.png', dpi=300)

# %%
cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(cnn_lstm_model, cnn_multi_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(cnn_multi_window.test, verbose=0)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 3s 13ms/step - loss: 0.0317 - mean_absolute_error: 0.0929 - val_loss: 0.0340 - val_mean_absolute_error: 0.1580
# Epoch 2/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0364 - val_loss: 0.0103 - val_mean_absolute_error: 0.0854
# Epoch 3/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0268 - val_loss: 0.0055 - val_mean_absolute_error: 0.0595
# Epoch 4/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0249 - val_loss: 0.0056 - val_mean_absolute_error: 0.0611
# Epoch 5/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0230 - val_loss: 0.0049 - val_mean_absolute_error: 0.0569
# Epoch 6/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0215 - val_loss: 0.0066 - val_mean_absolute_error: 0.0680
# Epoch 7/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0204 - val_loss: 0.0041 - val_mean_absolute_error: 0.0507
# Epoch 8/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0222 - val_loss: 0.0043 - val_mean_absolute_error: 0.0514
# Epoch 9/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0204 - val_loss: 0.0046 - val_mean_absolute_error: 0.0538
# Epoch 10/1000
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0191 - val_loss: 0.0044 - val_mean_absolute_error: 0.0520
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0520

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+value*0.07, s=str(round(value, 3)), ha='center')

# plt.ylim(0, 0.33)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH18_F14_peixeiro.png', dpi=300)
