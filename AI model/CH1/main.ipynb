# %% [markdown]
# ## AND運算值訓練

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 創建AND邏輯運算的輸入和輸出數據
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])

# 創建一個Sequential模型
model = Sequential()

# 添加一個具有兩個輸入神經元的全連接層
model.add(Dense(1, input_dim=2, activation='sigmoid'))

# 編譯模型（使用二元交叉熵損失和Adam優化器）
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 訓練模型
model.fit(X, y, epochs=100, verbose=2)

# 評估模型
loss, accuracy = model.evaluate(X, y)
print(f'損失: {loss:.4f}, 準確度: {accuracy:.4f}')

# 使用模型進行預測
predictions = model.predict(X)
print('預測結果:')
for i in range(len(X)):
    print(f'輸入: {X[i]}, 預測輸出: {predictions[i][0]:.4f}')
# Out:
# Epoch 1/100
# 1/1 - 1s - loss: 0.7992 - accuracy: 0.7500 - 678ms/epoch - 678ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.7988 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.7984 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.7980 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.7976 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.7972 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.7968 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.7964 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.7960 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.7956 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.7952 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.7948 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.7944 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.7940 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.7936 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.7932 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.7928 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.7924 - accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.7920 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.7916 - accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.7912 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.7908 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.7904 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.7900 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.7896 - accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.7892 - accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.7888 - accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.7884 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.7880 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.7876 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.7872 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.7868 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.7864 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.7860 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.7856 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.7852 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.7848 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.7845 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.7841 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.7837 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.7833 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.7829 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.7825 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.7821 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.7817 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.7813 - accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.7810 - accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.7806 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.7802 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.7798 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.7794 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.7790 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.7786 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.7782 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.7779 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.7775 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.7771 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.7767 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.7763 - accuracy: 0.7500 - 13ms/epoch - 13ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.7759 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.7756 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.7752 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.7748 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.7744 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.7740 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.7737 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.7733 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.7729 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.7725 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.7721 - accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.7718 - accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.7714 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.7710 - accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.7706 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.7703 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.7699 - accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.7695 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.7691 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.7688 - accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.7684 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.7680 - accuracy: 0.5000 - 11ms/epoch - 11ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.7676 - accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.7673 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.7669 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.7665 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.7662 - accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.7658 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.7654 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.7650 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.7647 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.7643 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.7639 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.7636 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.7632 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.7628 - accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.7625 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.7621 - accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.7617 - accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.7614 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.7610 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# 1/1 [==============================] - 0s 191ms/step - loss: 0.7606 - accuracy: 0.5000
# 損失: 0.7606, 準確度: 0.5000
# 1/1 [==============================] - 0s 117ms/step
# 預測結果:
# 輸入: [0 0], 預測輸出: 0.4754
# 輸入: [0 1], 預測輸出: 0.7667
# 輸入: [1 0], 預測輸出: 0.2130
# 輸入: [1 1], 預測輸出: 0.4953

# %% [markdown]
# ## 模擬神經元

# %%
import math
# 定義神經元的輸入權重和閾值
weights = [0.5, 0.3, -0.2]  # 輸入權重

# 簡單的激活函數
threshold = 0.4  # 閾值

# 定義神經元的輸入
inputs = [0.7, 0.2, 0.5]  # 輸入值

# 計算神經元的加權和
weighted_sum = 0
for i in range(len(weights)):
    weighted_sum += weights[i] * inputs[i]

# 判斷神經元是否激活（使用閾值函數）
if weighted_sum >= threshold:
    output = 1  # 激活
else:
    output = 0  # 不激活

# 印出神經元的輸出
print("神經元的輸出:", output)
# Out:
# 神經元的輸出: 0

# %% [markdown]
# ## KNN分類

# %%
# 匯入所需的函式庫
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris,load_wine
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 載入資料集（以鳶尾花數據集為例）
data = load_wine()
X = data.data
y = data.target

# 將資料集分為訓練集和測試集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# 初始化KNN分類器（這裡選擇K=3）
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# 訓練模型
knn_classifier.fit(X_train, y_train)

# 使用模型進行預測
y_pred = knn_classifier.predict(X_test)

# 計算模型的準確度
accuracy = accuracy_score(y_test, y_pred)
print("模型準確度：", accuracy)
# Out:
# 模型準確度： 0.7222222222222222
